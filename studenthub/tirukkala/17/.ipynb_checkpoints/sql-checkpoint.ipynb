# %% [markdown]
# #### Imports

# %%
import pandas as pd
import sqlite3
pd.set_option('max_colwidth', None)

# %% [markdown]
# #### Initiate an empty database

# %%
connection = sqlite3.connect(":memory:")

# %% [markdown]
# #### Create a table

# %%
# CREATE A TABLE
connection.execute('''CREATE TABLE faculty
             (
             id int,
             first_name text,
             last_name text,
             date_of_birth text
             )''')

# %% [markdown]
# #### Insert some data

# %%
# INSERT DATA
connection.execute('''
INSERT INTO faculty
VALUES ("1", "John", "Smith", "1970-01-02"
)
''')

# %%
# TRIVIAL TEST VIA SELECT
result = connection.execute("""
SELECT last_name, date_of_birth

FROM faculty
"""
)
result.fetchall()
# Out:
# [('Smith', '1970-01-02')]

# %% [markdown]
# #### Make the SQL database to a pandas DataFrame

# %%
pd.read_sql("""SELECT * FROM faculty""", connection)
# Out:
#    id first_name last_name date_of_birth
# 0   1       John     Smith    1970-01-02

# %% [markdown]
# ---

# %% [markdown]
# ## Cities Database
#
# Download the [Cities Database](http://oxrep.classics.ox.ac.uk/oxrep/docs/Hanson2016/Hanson2016_CitiesDatabase_OxREP.xlsx) of Hanson, J. W. (2016) _Cities Database_ (OXREP databases). Version 1.0. Accessed (date): <http://oxrep.classics.ox.ac.uk/databases/cities/>. DOI: <https://doi.org/10.5287/bodleian:eqapevAn8>
#
# In titles, replace all spaces with underscores and convert case to lowercase.

# %%
# This line resets the memory.
connection = sqlite3.connect(":memory:")

# Read the excel as pandas DataFrame
cities_df = pd.read_excel('Hanson2016_citiesDatabase_OxREP.xlsx', sheet_name = 'cities')

# Turn the DataFrame to SQL
cities_df.to_sql('cities', con = connection, index = False) # Why False?

cities_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 5>()
#       2 connection = sqlite3.connect(":memory:")
#       4 # Read the excel as pandas DataFrame
# ----> 5 cities_df = pd.read_excel('Hanson2016_citiesDatabase_OxREP.xlsx', sheet_name = 'cities')
#       7 # Turn the DataFrame to SQL
#       8 cities_df.to_sql('cities', con = connection, index = False) # Why False?
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:1376, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1374     ext = "xls"
#    1375 else:
# -> 1376     ext = inspect_excel_format(
#    1377         content_or_path=path_or_buffer, storage_options=storage_options
#    1378     )
#    1379     if ext is None:
#    1380         raise ValueError(
#    1381             "Excel file format cannot be determined, you must specify "
#    1382             "an engine manually."
#    1383         )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:1250, in inspect_excel_format(content_or_path, storage_options)
#    1247 if isinstance(content_or_path, bytes):
#    1248     content_or_path = BytesIO(content_or_path)
# -> 1250 with get_handle(
#    1251     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252 ) as handle:
#    1253     stream = handle.handle
#    1254     stream.seek(0)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:798, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#    (...)
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
# --> 798         handle = open(handle, ioargs.mode)
#     799     handles.append(handle)
#     801 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Hanson2016_citiesDatabase_OxREP.xlsx'

# %% [markdown]
# #### Let's perform a query

# %%
pd.read_sql("SELECT * FROM cities", connection).head()

# %% [markdown]
# #### `WHERE`

# %%
pd.read_sql("""

SELECT id, ancient_toponym, modern_toponym, province, country, start_date, end_date

FROM cities

WHERE province = 'Macedonia'

""", connection)
# Out:
#                  id        ancient_toponym modern_toponym   province  \
# 0   Hanson2016_1146                Amantia           Klos  Macedonia
# 1   Hanson2016_1147             Amphipolis       Amfipoli  Macedonia
# 2   Hanson2016_1148  Apollonia (Macedonia)         Pojani  Macedonia
# 3   Hanson2016_1149     Beroea (Macedonia)          Veria  Macedonia
# 4   Hanson2016_1150                 Byllis       Gradisht  Macedonia
# 5   Hanson2016_1151             Cassandrea     Cassandrea  Macedonia
# 6   Hanson2016_1152                   Dium           Dion  Macedonia
# 7   Hanson2016_1153             Dyrrachium         Durrës  Macedonia
# 8   Hanson2016_1154                 Edessa         Edessa  Macedonia
# 9   Hanson2016_1155   Heraclea (Macedonia)         Bitola  Macedonia
# 10  Hanson2016_1156              Lychnidus         Ochrid  Macedonia
# 11  Hanson2016_1157   Neapolis (Macedonia)         Kavala  Macedonia
# 12  Hanson2016_1158      Pella (Macedonia)          Pella  Macedonia
# 13  Hanson2016_1159               Philippi       Krenides  Macedonia
# 14  Hanson2016_1160                  Stobi          Stobi  Macedonia
# 15  Hanson2016_1161                 Thasos         Thasos  Macedonia
# 16  Hanson2016_1162           Thessalonica   Thessaloniki  Macedonia
# 17  Hanson2016_1163                 Torone         Toroni  Macedonia
#
#       country  start_date end_date
# 0     Albania        -600     None
# 1      Greece        -437     None
# 2     Albania        -588     None
# 3      Greece        -400     None
# 4     Albania        -400     None
# 5      Greece        -600     None
# 6      Greece        -400     None
# 7     Albania        -627     None
# 8      Greece        -600     None
# 9   Macedonia        -359     None
# 10  Macedonia        -600     None
# 11     Greece        -650     None
# 12     Greece        -413     None
# 13     Greece        -360     None
# 14  Macedonia        -229     None
# 15     Greece        -700     None
# 16     Greece        -316     None
# 17     Greece        -400     None

# %% [markdown]
# #### `AND`

# %%
pd.read_sql("""

SELECT id, ancient_toponym, modern_toponym, province, country, start_date, end_date

FROM cities

WHERE province = 'Macedonia'

AND start_date > -323

""", connection)
# Out:
#                 id ancient_toponym modern_toponym   province    country  \
# 0  Hanson2016_1160           Stobi          Stobi  Macedonia  Macedonia
# 1  Hanson2016_1162    Thessalonica   Thessaloniki  Macedonia     Greece
#
#    start_date end_date
# 0        -229     None
# 1        -316     None

# %% [markdown]
# #### What is NULL?

# %%
pd.read_sql("""

SELECT id, ancient_toponym, modern_toponym, province, country, start_date, end_date

FROM cities

WHERE province = 'Macedonia'

AND end_date IS NULL

""", connection).head()
# Out:
#                 id        ancient_toponym modern_toponym   province  country  \
# 0  Hanson2016_1146                Amantia           Klos  Macedonia  Albania
# 1  Hanson2016_1147             Amphipolis       Amfipoli  Macedonia   Greece
# 2  Hanson2016_1148  Apollonia (Macedonia)         Pojani  Macedonia  Albania
# 3  Hanson2016_1149     Beroea (Macedonia)          Veria  Macedonia   Greece
# 4  Hanson2016_1150                 Byllis       Gradisht  Macedonia  Albania
#
#    start_date end_date
# 0        -600     None
# 1        -437     None
# 2        -588     None
# 3        -400     None
# 4        -400     None

# %% [markdown]
# #### Subquery: Find all cities older than Torone in Macedonia

# %%
pd.read_sql("""

SELECT id, ancient_toponym, modern_toponym, province, country, start_date, end_date

FROM cities

WHERE province = 'Macedonia'

AND start_date < 
            (SELECT start_date 

            FROM cities

            WHERE ancient_toponym = "Torone"
            )

""", connection)
# Out:
#                 id        ancient_toponym modern_toponym   province  \
# 0  Hanson2016_1146                Amantia           Klos  Macedonia
# 1  Hanson2016_1147             Amphipolis       Amfipoli  Macedonia
# 2  Hanson2016_1148  Apollonia (Macedonia)         Pojani  Macedonia
# 3  Hanson2016_1151             Cassandrea     Cassandrea  Macedonia
# 4  Hanson2016_1153             Dyrrachium         Durrës  Macedonia
# 5  Hanson2016_1154                 Edessa         Edessa  Macedonia
# 6  Hanson2016_1156              Lychnidus         Ochrid  Macedonia
# 7  Hanson2016_1157   Neapolis (Macedonia)         Kavala  Macedonia
# 8  Hanson2016_1158      Pella (Macedonia)          Pella  Macedonia
# 9  Hanson2016_1161                 Thasos         Thasos  Macedonia
#
#      country  start_date end_date
# 0    Albania        -600     None
# 1     Greece        -437     None
# 2    Albania        -588     None
# 3     Greece        -600     None
# 4    Albania        -627     None
# 5     Greece        -600     None
# 6  Macedonia        -600     None
# 7     Greece        -650     None
# 8     Greece        -413     None
# 9     Greece        -700     None

# %% [markdown]
# #### Let's select all counties where there were ancient cities

# %%
pd.read_sql("""

SELECT DISTINCT country 

FROM cities

ORDER BY country

""", connection)
# Out:
#                    country
# 0                  Albania
# 1                  Algeria
# 2                  Austria
# 3                  Belgium
# 4   Bosnia and Herzegovina
# 5                 Bulgaria
# 6                  Croatia
# 7                   Cyprus
# 8                    Egypt
# 9                   France
# 10                 Germany
# 11                  Greece
# 12                 Hungary
# 13                  Israel
# 14                   Italy
# 15                  Jordan
# 16                  Kosovo
# 17                 Lebanon
# 18                   Libya
# 19               Macedonia
# 20                   Malta
# 21              Montenegro
# 22                 Morocco
# 23             Netherlands
# 24         Northern Cyprus
# 25                Portugal
# 26                 Romania
# 27                  Serbia
# 28                Slovenia
# 29                   Spain
# 30             Switzerland
# 31                   Syria
# 32                 Tunisia
# 33                  Turkey
# 34          United Kingdom

# %% [markdown]
# #### ` ORDER BY`

# %%
pd.read_sql("""

SELECT DISTINCT country

FROM cities

WHERE province = 'Macedonia'

""", connection)

# %% [markdown]
# #### `DISTINCT`

# %%
pd.read_sql("""

SELECT DISTINCT province

FROM cities

WHERE longitude > (SELECT latitude 
                    FROM cities
                    WHERE ancient_toponym = 'Athenae')
AND start_date < (SELECT start_date 
                    FROM cities
                    WHERE ancient_toponym = 'Athenae')

""", connection)
# Out:
# Empty DataFrame
# Columns: [province]
# Index: []

# %% [markdown]
# #### Exercise: Find all the countries that have cities on ancient Macedonia

# %%
pd.read_sql("""

SELECT DISTINCT country

FROM cities

WHERE province = 'Macedonia'

""", connection)

# %% [markdown]
# #### Exercise: Find all provinces eastern than Athens (Athenae) that have cities are older than Athens

# %%
pd.read_sql("""

SELECT DISTINCT province

FROM cities

WHERE latitude > (SELECT latitude 
                    FROM cities
                    WHERE ancient_toponym = 'Athenae')
AND start_date > (SELECT start_date 
                    FROM cities
                    WHERE ancient_toponym = 'Athenae')
                    
""", connection)
# Out:
#                                 province
# 0                                 Achaea
# 1                          Alpes Cottiae
# 2               Alpes Graiae et Poeninae
# 3                        Alpes Maritimae
# 4                                   Asia
# 5                                Baetica
# 6                     Bithynia et Pontus
# 7                              Britannia
# 8                  Cappadocia et Galatia
# 9                    Corsica et Sardinia
# 10                                 Dacia
# 11                              Dalmatia
# 12                      Gallia Aquitania
# 13                        Gallia Belgica
# 14                    Gallia Lugdunensis
# 15                    Gallia Narbonensis
# 16                     Germania Inferior
# 17                     Germania Superior
# 18                Hispania Tarraconensis
# 19        Italia (I Latium and Campania)
# 20        Italia (II Apulia et Calabria)
# 21        Italia (III Lucania et Brutii)
# 22                   Italia (IV Samnium)
# 23                    Italia (V Picenum)
# 24  Italia (VI Umbria and Ager Gallicus)
# 25                  Italia (VII Etruria)
# 26                 Italia (VIII Aemilia)
# 27                   Italia (IX Liguria)
# 28         Italia (X Venetia et Histria)
# 29               Italia (XI Transpadana)
# 30                             Lusitania
# 31                    Lycia et Pamphylia
# 32                             Macedonia
# 33                       Moesia Inferior
# 34                       Moesia Superior
# 35                               Noricum
# 36                     Pannonia Inferior
# 37                     Pannonia Superior
# 38                                Raetia
# 39                               Silicia
# 40                               Thracia

# %% [markdown]
# #### Exercise: Count all provinces eastern than Athens (Athenae) that have cities are older than Athens

# %%
pd.read_sql("""

SELECT DISTINCT province, count(*) as count 

FROM cities

WHERE latitude > (SELECT latitude 
                    FROM cities
                    WHERE ancient_toponym = 'Athenae')
AND start_date > (SELECT start_date 
                    FROM cities
                    WHERE ancient_toponym = 'Athenae')
                    

""", connection)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 pd.read_sql("""
#       2
#       3 SELECT DISTINCT province, count(*) as count
#       4
#       5 FROM cities
#       6
#       7 WHERE latitude > (SELECT latitude
#       8                     FROM cities
#       9                     WHERE ancient_toponym = 'Athenae')
#      10 AND start_date > (SELECT start_date
#      11                     FROM cities
#      12                     WHERE ancient_toponym = 'Athenae')
#      13
#      14
#      15 """, connection)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# #### Read the sheet _monuments_ of Hanson2016_citiesDatabase_OxREP

# %%
monuments_df = pd.read_excel('Hanson2016_citiesDatabase_OxREP.xlsx', sheet_name = 'monuments')

monuments_df.to_sql('monuments', con = connection, index = False)

pd.read_sql("SELECT * FROM monuments", connection).head(2)
# Out:
#              id  structure
# 0  Hanson2016_1  Acropolis
# 1  Hanson2016_1      Agora

# %% [markdown]
# Notice that we are not creating a new connection

# %%
pd.read_sql("""

SELECT cities.ancient_toponym, monuments.structure

FROM monuments

JOIN cities ON cities.id = monuments.id


""", connection)
# Out:
#      ancient_toponym           structure
# 0               Abae           Acropolis
# 1               Abae               Agora
# 2               Abae    Temple of Apollo
# 3               Abae             Theatre
# 4               Abae               Walls
# ...              ...                 ...
# 9466     Seuthopolis  Temple of Dionysus
# 9467     Seuthopolis          Urban grid
# 9468     Seuthopolis               Walls
# 9469         Bararus             Theatre
# 9470       Aventicum             Theatre
#
# [9471 rows x 2 columns]

# %% [markdown]
# #### Exercise create an ordered list with the city of each province that has the most monuments along with the counts of the monuments

# %%
pd.read_sql("""

SELECT DISTINCT province

FROM cities

WHERE latitude > (SELECT latitude 
                    FROM cities
                    WHERE ancient_toponym = 'Athenae')
AND start_date > (SELECT start_date 
                    FROM cities
                    WHERE ancient_toponym = 'Athenae')
                    
""", connection)

# %% [markdown]
# #### What about `iloc` and `loc`?

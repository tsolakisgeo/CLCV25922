# %%
import pandas as pd
from random import randint
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv("pleiades-places-latest.csv")

# %%
df[([df['id'] == '570685']) | ([df['id'] == "541138"]) | ([df['id'] == '579885']) | ([df['id'] == '550696']) | ([df['id'] == '423025'])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df[([df['id'] == '570685']) | ([df['id'] == "541138"]) | ([df['id'] == '579885']) | ([df['id'] == '550696']) | ([df['id'] == '423025'])]
#
# TypeError: unsupported operand type(s) for |: 'list' and 'list'

# %%
df[(df['id'] == 570685) | (df['id'] == 541138) | (df['id'] == 579885) | (df['id'] == 550696) | (df['id'] == 423025)]
# Out:
#                                                  authors                                        bbox                                       connectsWith               created                        creators  currentVersion                                        description                                             extent                  featureTypes     geoContext                                 hasConnectionsWith      id locationPrecision  maxDate  minDate              modified            path    reprLat                  reprLatLong   reprLong                                               tags timePeriods                                    timePeriodsKeys timePeriodsRange            title                               uid
# 11683  Foss, C., G. Reger, S. Mitchell, R. Talbert, S...   25.898431, 38.975668, 26.611272, 39.34095                                             560221  2019-08-28T13:28:02Z  C. Foss, G. Reger, S. Mitchell             9.0  Lesbos is an island of the northeastern Aegean...  {"type": "Polygon", "coordinates": [[[26.48097...                        island     Lesbos GRE  550689,550435,550837,550430,550885,550719,5506...  550696           related   2100.0   -750.0  2020-11-08T16:52:01Z  /places/550696  39.169017  39.1690170716,26.2501593941  26.250159                                                NaN       ACHRM  archaic,classical,hellenistic-republican,roman...    -750.0,2100.0  Lesbos (island)  26ef7dd2cc85ab64c4d410698052191d
# 13333  Fossey, J., J. Morin, B. Kiesling, S. Gillies,...  23.317355, 38.319076, 23.317799, 38.319236                                             540689  2018-06-08T11:31:53Z             J. Fossey, J. Morin            16.0  The ancient city of Thebes in Boeotia (modern ...  {"type": "LineString", "coordinates": [[23.317...                    settlement         Thivai                                          239936126  541138           precise   2100.0  -1600.0  2022-05-09T17:18:39Z  /places/541138  38.319156          38.319156,23.317577  23.317577  dare:ancient=1, dare:major=1, dare:feature=maj...     LACHRLM  late-helladic,archaic,classical,hellenistic-re...   -1600.0,2100.0    Thebai/Thebae  1f82a54386e0b84265824fda54157fda
# 21162  Reger, G., J. McK. Camp II, B. Kiesling, S. Gi...   22.42366, 37.073678, 22.430937, 37.082132                                      570406,570248  2022-01-13T20:44:00Z       G. Reger, J. McK. Camp II             9.0  Sparta was a prominent city-state (polis) of a...  {"type": "LineString", "coordinates": [[22.430...  settlement, temple, temple-2         Sparti                                139216315,757663383  570685           precise    300.0   -850.0  2022-01-13T22:15:05Z  /places/570685  37.077905         37.077905,22.4272985  22.427298  dare:ancient=1, dare:major=1, dare:feature=maj...       MACHR  middle-geometric,archaic,classical,hellenistic...     -850.0,300.0           Sparta  aa8187aaa965b2af3cba1a0cfd8c0d79
# 21778  Traill, J., B. Kiesling, S. Gillies, C. Lee, J...  23.619913, 37.937222, 23.849968, 38.019497                                             579888  2018-06-07T20:56:36Z                     J.S. Traill            28.0  A major Greek city-state and the principal cit...  {"type": "Polygon", "coordinates": [[[23.64460...                    settlement  Athina/Athens  585128,728329644,235795850,580123,813654446,58...  579885           related   2100.0   -750.0  2022-08-25T22:21:35Z  /places/579885  37.972454    37.972453603,23.726268222  23.726268  dare:ancient=1, dare:major=1, dare:feature=maj...      ACHRLM  archaic,classical,hellenistic-republican,roman...    -750.0,2100.0          Athenae  aef8271177d5afba233b2b97dcb52af4
# 35736  Quilici, L., S. Quilici Gigli, B. Kiesling, S....  12.486137, 41.891775, 12.486137, 41.891775  303999556,502042016,93042695,741499023,6992565...  2018-06-07T19:48:13Z    L. Quilici, S. Quilici Gigli            67.0      The capital of the Roman Republic and Empire.  {"type": "Point", "coordinates": [12.486137, 4...             urban, settlement      Roma/Rome  571005605,769033983,646461227,285857974,874299...  423025           precise   2100.0   -750.0  2021-12-17T19:27:27Z  /places/423025  41.891775          41.891775,12.486137  12.486137  dare:major=1, dare:feature=major settlement, U...      ACHRLM  archaic,classical,hellenistic-republican,roman...    -750.0,2100.0             Roma  dd0d9cee472b7c974729908f4daf0108

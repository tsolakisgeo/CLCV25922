# %% [markdown]
# # [Regular expressions](https://www.regular-expressions.info/tutorial.html)
#
# "a regular expression is a pattern describing a certain amount of text"

# %% [markdown]
# #### There are special characters:
#
# . + * ? ^ $ ( ) [ ] { } | \
#
# Each one of them has a specific meaning. If you want to search for those characters you need to use a backshash

# %% [markdown]
# #### Import regex library

# %%
import re

# %% [markdown]
# #### Raw strings
# _An 'r' before a string tells the Python interpreter to treat backslashes as a literal (raw) character_

# %%
print('This is a line \nand this is a new one')
print(r'This is a line \nand this is a new one')
# Out:
# This is a line
# and this is a new one
# This is a line \nand this is a new one

# %% [markdown]
# #### How are regex useful?
# For example, imagine that you have a long list of dates one hunderd times larger that the above. How one can search for all dates in August?

# %%
dates = """
08-12-2012
06-07-2015
08/08/08
04.08.08
09.09.2019
9.9.2019
8.9.2019
"""

# %%
results = re.findall(r'[\d]?8[-\/\.][\d]{1,2}[-/\.][\d]{2,4}', dates)
print(results)
# Out:
# ['08-12-2012', '08/08/08', '8.9.2019']

# %% [markdown]
# #### Text string

# %%
with open(faketext) as f:
    faketext = f.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 with open(faketext) as f:
#       2     faketext = f.read()
#
# NameError: name 'faketext' is not defined

# %%
faketext = """A

Alex
Georgios
Shama
Suleiman
Liam
Olivia
Noah
Emma
Oliver
Charlotte
Elijah
Amelia
James
Ava
William
Sophia
Benjamin
Isabella
Lucas
Mia
Henry
Evelyn
Theodore
Harper

08-12-2012
06-07-2015
08/08/08
04.08.08
09.09.2019
9.9.2019
8.9.2019

202-555-0166
201*555*0177
(202) 555-0128
(201)555-0178
202 555 0198
900-555-0166
800*555*0177
(900) 555-0128
(800)555-0178
900 555 0198
800.555.0199
800.555.0152
201.555.0199
201.555.0152


Mr. Darcy
Dr. Tsolakis
Prof. Cartledge
Mr. T
Mrs Robinson
Mr. Bean
Miss Piggy 


JohnDoe@gmail.com
John_Doe@gmail.com
JohnDoe@facebook.net
john.doe@uchicago.edu
sincere.jakubowski@gutkowski.com
kerluke.cierra@bradtke.com
nromaguera@yahoo.com
john-doe@gmail.com
johndoe1990@gmail.com

Z"""
# Using 3 quotation marks allows you to use more than one line

# %% [markdown]
# #### finditer

# %% [markdown]
# ### Word Characters

# %% [markdown]
# #### .
# Any character except a new line

# %%
mypattern = re.compile(r'.e')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(4, 6), match='le'>
# <re.Match object; span=(8, 10), match='Ge'>
# <re.Match object; span=(25, 27), match='le'>
# <re.Match object; span=(57, 59), match='ve'>
# <re.Match object; span=(68, 70), match='te'>
# <re.Match object; span=(79, 81), match='me'>
# <re.Match object; span=(87, 89), match='me'>
# <re.Match object; span=(110, 112), match='Be'>
# <re.Match object; span=(122, 124), match='be'>
# <re.Match object; span=(138, 140), match='He'>
# <re.Match object; span=(145, 147), match='ve'>
# <re.Match object; span=(152, 154), match='he'>
# <re.Match object; span=(157, 159), match='re'>
# <re.Match object; span=(163, 165), match='pe'>
# <re.Match object; span=(461, 463), match='le'>
# <re.Match object; span=(464, 466), match='ge'>
# <re.Match object; span=(490, 492), match='Be'>
# <re.Match object; span=(514, 516), match='oe'>
# <re.Match object; span=(533, 535), match='oe'>
# <re.Match object; span=(551, 553), match='oe'>
# <re.Match object; span=(556, 558), match='ce'>
# <re.Match object; span=(563, 565), match='ne'>
# <re.Match object; span=(573, 575), match='oe'>
# <re.Match object; span=(584, 586), match='.e'>
# <re.Match object; span=(592, 594), match='ce'>
# <re.Match object; span=(594, 596), match='re'>
# <re.Match object; span=(622, 624), match='ke'>
# <re.Match object; span=(627, 629), match='ke'>
# <re.Match object; span=(631, 633), match='ie'>
# <re.Match object; span=(642, 644), match='ke'>
# <re.Match object; span=(655, 657), match='ue'>
# <re.Match object; span=(676, 678), match='oe'>
# <re.Match object; span=(694, 696), match='oe'>

# %% [markdown]
# #### \d
# Digits

# %%
mypattern = re.compile(r'\d\d')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(168, 170), match='08'>
# <re.Match object; span=(171, 173), match='12'>
# <re.Match object; span=(174, 176), match='20'>
# <re.Match object; span=(176, 178), match='12'>
# <re.Match object; span=(179, 181), match='06'>
# <re.Match object; span=(182, 184), match='07'>
# <re.Match object; span=(185, 187), match='20'>
# <re.Match object; span=(187, 189), match='15'>
# <re.Match object; span=(190, 192), match='08'>
# <re.Match object; span=(193, 195), match='08'>
# <re.Match object; span=(196, 198), match='08'>
# <re.Match object; span=(199, 201), match='04'>
# <re.Match object; span=(202, 204), match='08'>
# <re.Match object; span=(205, 207), match='08'>
# <re.Match object; span=(208, 210), match='09'>
# <re.Match object; span=(211, 213), match='09'>
# <re.Match object; span=(214, 216), match='20'>
# <re.Match object; span=(216, 218), match='19'>
# <re.Match object; span=(223, 225), match='20'>
# <re.Match object; span=(225, 227), match='19'>
# <re.Match object; span=(232, 234), match='20'>
# <re.Match object; span=(234, 236), match='19'>
# <re.Match object; span=(238, 240), match='20'>
# <re.Match object; span=(242, 244), match='55'>
# <re.Match object; span=(246, 248), match='01'>
# <re.Match object; span=(248, 250), match='66'>
# <re.Match object; span=(251, 253), match='20'>
# <re.Match object; span=(255, 257), match='55'>
# <re.Match object; span=(259, 261), match='01'>
# <re.Match object; span=(261, 263), match='77'>
# <re.Match object; span=(265, 267), match='20'>
# <re.Match object; span=(270, 272), match='55'>
# <re.Match object; span=(274, 276), match='01'>
# <re.Match object; span=(276, 278), match='28'>
# <re.Match object; span=(280, 282), match='20'>
# <re.Match object; span=(284, 286), match='55'>
# <re.Match object; span=(288, 290), match='01'>
# <re.Match object; span=(290, 292), match='78'>
# <re.Match object; span=(293, 295), match='20'>
# <re.Match object; span=(297, 299), match='55'>
# <re.Match object; span=(301, 303), match='01'>
# <re.Match object; span=(303, 305), match='98'>
# <re.Match object; span=(306, 308), match='90'>
# <re.Match object; span=(310, 312), match='55'>
# <re.Match object; span=(314, 316), match='01'>
# <re.Match object; span=(316, 318), match='66'>
# <re.Match object; span=(319, 321), match='80'>
# <re.Match object; span=(323, 325), match='55'>
# <re.Match object; span=(327, 329), match='01'>
# <re.Match object; span=(329, 331), match='77'>
# <re.Match object; span=(333, 335), match='90'>
# <re.Match object; span=(338, 340), match='55'>
# <re.Match object; span=(342, 344), match='01'>
# <re.Match object; span=(344, 346), match='28'>
# <re.Match object; span=(348, 350), match='80'>
# <re.Match object; span=(352, 354), match='55'>
# <re.Match object; span=(356, 358), match='01'>
# <re.Match object; span=(358, 360), match='78'>
# <re.Match object; span=(361, 363), match='90'>
# <re.Match object; span=(365, 367), match='55'>
# <re.Match object; span=(369, 371), match='01'>
# <re.Match object; span=(371, 373), match='98'>
# <re.Match object; span=(374, 376), match='80'>
# <re.Match object; span=(378, 380), match='55'>
# <re.Match object; span=(382, 384), match='01'>
# <re.Match object; span=(384, 386), match='99'>
# <re.Match object; span=(387, 389), match='80'>
# <re.Match object; span=(391, 393), match='55'>
# <re.Match object; span=(395, 397), match='01'>
# <re.Match object; span=(397, 399), match='52'>
# <re.Match object; span=(400, 402), match='20'>
# <re.Match object; span=(404, 406), match='55'>
# <re.Match object; span=(408, 410), match='01'>
# <re.Match object; span=(410, 412), match='99'>
# <re.Match object; span=(413, 415), match='20'>
# <re.Match object; span=(417, 419), match='55'>
# <re.Match object; span=(421, 423), match='01'>
# <re.Match object; span=(423, 425), match='52'>
# <re.Match object; span=(696, 698), match='19'>
# <re.Match object; span=(698, 700), match='90'>

# %% [markdown]
# #### \D
# Not a digit

# %%
mypattern = re.compile(r'\D\D')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 2), match='A\n'>
# <re.Match object; span=(2, 4), match='\nA'>
# <re.Match object; span=(4, 6), match='le'>
# <re.Match object; span=(6, 8), match='x\n'>
# <re.Match object; span=(8, 10), match='Ge'>
# <re.Match object; span=(10, 12), match='or'>
# <re.Match object; span=(12, 14), match='gi'>
# <re.Match object; span=(14, 16), match='os'>
# <re.Match object; span=(16, 18), match='\nS'>
# <re.Match object; span=(18, 20), match='ha'>
# <re.Match object; span=(20, 22), match='ma'>
# <re.Match object; span=(22, 24), match='\nS'>
# <re.Match object; span=(24, 26), match='ul'>
# <re.Match object; span=(26, 28), match='ei'>
# <re.Match object; span=(28, 30), match='ma'>
# <re.Match object; span=(30, 32), match='n\n'>
# <re.Match object; span=(32, 34), match='Li'>
# <re.Match object; span=(34, 36), match='am'>
# <re.Match object; span=(36, 38), match='\nO'>
# <re.Match object; span=(38, 40), match='li'>
# <re.Match object; span=(40, 42), match='vi'>
# <re.Match object; span=(42, 44), match='a\n'>
# <re.Match object; span=(44, 46), match='No'>
# <re.Match object; span=(46, 48), match='ah'>
# <re.Match object; span=(48, 50), match='\nE'>
# <re.Match object; span=(50, 52), match='mm'>
# <re.Match object; span=(52, 54), match='a\n'>
# <re.Match object; span=(54, 56), match='Ol'>
# <re.Match object; span=(56, 58), match='iv'>
# <re.Match object; span=(58, 60), match='er'>
# <re.Match object; span=(60, 62), match='\nC'>
# <re.Match object; span=(62, 64), match='ha'>
# <re.Match object; span=(64, 66), match='rl'>
# <re.Match object; span=(66, 68), match='ot'>
# <re.Match object; span=(68, 70), match='te'>
# <re.Match object; span=(70, 72), match='\nE'>
# <re.Match object; span=(72, 74), match='li'>
# <re.Match object; span=(74, 76), match='ja'>
# <re.Match object; span=(76, 78), match='h\n'>
# <re.Match object; span=(78, 80), match='Am'>
# <re.Match object; span=(80, 82), match='el'>
# <re.Match object; span=(82, 84), match='ia'>
# <re.Match object; span=(84, 86), match='\nJ'>
# <re.Match object; span=(86, 88), match='am'>
# <re.Match object; span=(88, 90), match='es'>
# <re.Match object; span=(90, 92), match='\nA'>
# <re.Match object; span=(92, 94), match='va'>
# <re.Match object; span=(94, 96), match='\nW'>
# <re.Match object; span=(96, 98), match='il'>
# <re.Match object; span=(98, 100), match='li'>
# <re.Match object; span=(100, 102), match='am'>
# <re.Match object; span=(102, 104), match='\nS'>
# <re.Match object; span=(104, 106), match='op'>
# <re.Match object; span=(106, 108), match='hi'>
# <re.Match object; span=(108, 110), match='a\n'>
# <re.Match object; span=(110, 112), match='Be'>
# <re.Match object; span=(112, 114), match='nj'>
# <re.Match object; span=(114, 116), match='am'>
# <re.Match object; span=(116, 118), match='in'>
# <re.Match object; span=(118, 120), match='\nI'>
# <re.Match object; span=(120, 122), match='sa'>
# <re.Match object; span=(122, 124), match='be'>
# <re.Match object; span=(124, 126), match='ll'>
# <re.Match object; span=(126, 128), match='a\n'>
# <re.Match object; span=(128, 130), match='Lu'>
# <re.Match object; span=(130, 132), match='ca'>
# <re.Match object; span=(132, 134), match='s\n'>
# <re.Match object; span=(134, 136), match='Mi'>
# <re.Match object; span=(136, 138), match='a\n'>
# <re.Match object; span=(138, 140), match='He'>
# <re.Match object; span=(140, 142), match='nr'>
# <re.Match object; span=(142, 144), match='y\n'>
# <re.Match object; span=(144, 146), match='Ev'>
# <re.Match object; span=(146, 148), match='el'>
# <re.Match object; span=(148, 150), match='yn'>
# <re.Match object; span=(150, 152), match='\nT'>
# <re.Match object; span=(152, 154), match='he'>
# <re.Match object; span=(154, 156), match='od'>
# <re.Match object; span=(156, 158), match='or'>
# <re.Match object; span=(158, 160), match='e\n'>
# <re.Match object; span=(160, 162), match='Ha'>
# <re.Match object; span=(162, 164), match='rp'>
# <re.Match object; span=(164, 166), match='er'>
# <re.Match object; span=(166, 168), match='\n\n'>
# <re.Match object; span=(236, 238), match='\n\n'>
# <re.Match object; span=(263, 265), match='\n('>
# <re.Match object; span=(268, 270), match=') '>
# <re.Match object; span=(278, 280), match='\n('>
# <re.Match object; span=(331, 333), match='\n('>
# <re.Match object; span=(336, 338), match=') '>
# <re.Match object; span=(346, 348), match='\n('>
# <re.Match object; span=(425, 427), match='\n\n'>
# <re.Match object; span=(427, 429), match='\nM'>
# <re.Match object; span=(429, 431), match='r.'>
# <re.Match object; span=(431, 433), match=' D'>
# <re.Match object; span=(433, 435), match='ar'>
# <re.Match object; span=(435, 437), match='cy'>
# <re.Match object; span=(437, 439), match='\nD'>
# <re.Match object; span=(439, 441), match='r.'>
# <re.Match object; span=(441, 443), match=' T'>
# <re.Match object; span=(443, 445), match='so'>
# <re.Match object; span=(445, 447), match='la'>
# <re.Match object; span=(447, 449), match='ki'>
# <re.Match object; span=(449, 451), match='s\n'>
# <re.Match object; span=(451, 453), match='Pr'>
# <re.Match object; span=(453, 455), match='of'>
# <re.Match object; span=(455, 457), match='. '>
# <re.Match object; span=(457, 459), match='Ca'>
# <re.Match object; span=(459, 461), match='rt'>
# <re.Match object; span=(461, 463), match='le'>
# <re.Match object; span=(463, 465), match='dg'>
# <re.Match object; span=(465, 467), match='e\n'>
# <re.Match object; span=(467, 469), match='Mr'>
# <re.Match object; span=(469, 471), match='. '>
# <re.Match object; span=(471, 473), match='T\n'>
# <re.Match object; span=(473, 475), match='Mr'>
# <re.Match object; span=(475, 477), match='s '>
# <re.Match object; span=(477, 479), match='Ro'>
# <re.Match object; span=(479, 481), match='bi'>
# <re.Match object; span=(481, 483), match='ns'>
# <re.Match object; span=(483, 485), match='on'>
# <re.Match object; span=(485, 487), match='\nM'>
# <re.Match object; span=(487, 489), match='r.'>
# <re.Match object; span=(489, 491), match=' B'>
# <re.Match object; span=(491, 493), match='ea'>
# <re.Match object; span=(493, 495), match='n\n'>
# <re.Match object; span=(495, 497), match='Mi'>
# <re.Match object; span=(497, 499), match='ss'>
# <re.Match object; span=(499, 501), match=' P'>
# <re.Match object; span=(501, 503), match='ig'>
# <re.Match object; span=(503, 505), match='gy'>
# <re.Match object; span=(505, 507), match=' \n'>
# <re.Match object; span=(507, 509), match='\n\n'>
# <re.Match object; span=(509, 511), match='Jo'>
# <re.Match object; span=(511, 513), match='hn'>
# <re.Match object; span=(513, 515), match='Do'>
# <re.Match object; span=(515, 517), match='e@'>
# <re.Match object; span=(517, 519), match='gm'>
# <re.Match object; span=(519, 521), match='ai'>
# <re.Match object; span=(521, 523), match='l.'>
# <re.Match object; span=(523, 525), match='co'>
# <re.Match object; span=(525, 527), match='m\n'>
# <re.Match object; span=(527, 529), match='Jo'>
# <re.Match object; span=(529, 531), match='hn'>
# <re.Match object; span=(531, 533), match='_D'>
# <re.Match object; span=(533, 535), match='oe'>
# <re.Match object; span=(535, 537), match='@g'>
# <re.Match object; span=(537, 539), match='ma'>
# <re.Match object; span=(539, 541), match='il'>
# <re.Match object; span=(541, 543), match='.c'>
# <re.Match object; span=(543, 545), match='om'>
# <re.Match object; span=(545, 547), match='\nJ'>
# <re.Match object; span=(547, 549), match='oh'>
# <re.Match object; span=(549, 551), match='nD'>
# <re.Match object; span=(551, 553), match='oe'>
# <re.Match object; span=(553, 555), match='@f'>
# <re.Match object; span=(555, 557), match='ac'>
# <re.Match object; span=(557, 559), match='eb'>
# <re.Match object; span=(559, 561), match='oo'>
# <re.Match object; span=(561, 563), match='k.'>
# <re.Match object; span=(563, 565), match='ne'>
# <re.Match object; span=(565, 567), match='t\n'>
# <re.Match object; span=(567, 569), match='jo'>
# <re.Match object; span=(569, 571), match='hn'>
# <re.Match object; span=(571, 573), match='.d'>
# <re.Match object; span=(573, 575), match='oe'>
# <re.Match object; span=(575, 577), match='@u'>
# <re.Match object; span=(577, 579), match='ch'>
# <re.Match object; span=(579, 581), match='ic'>
# <re.Match object; span=(581, 583), match='ag'>
# <re.Match object; span=(583, 585), match='o.'>
# <re.Match object; span=(585, 587), match='ed'>
# <re.Match object; span=(587, 589), match='u\n'>
# <re.Match object; span=(589, 591), match='si'>
# <re.Match object; span=(591, 593), match='nc'>
# <re.Match object; span=(593, 595), match='er'>
# <re.Match object; span=(595, 597), match='e.'>
# <re.Match object; span=(597, 599), match='ja'>
# <re.Match object; span=(599, 601), match='ku'>
# <re.Match object; span=(601, 603), match='bo'>
# <re.Match object; span=(603, 605), match='ws'>
# <re.Match object; span=(605, 607), match='ki'>
# <re.Match object; span=(607, 609), match='@g'>
# <re.Match object; span=(609, 611), match='ut'>
# <re.Match object; span=(611, 613), match='ko'>
# <re.Match object; span=(613, 615), match='ws'>
# <re.Match object; span=(615, 617), match='ki'>
# <re.Match object; span=(617, 619), match='.c'>
# <re.Match object; span=(619, 621), match='om'>
# <re.Match object; span=(621, 623), match='\nk'>
# <re.Match object; span=(623, 625), match='er'>
# <re.Match object; span=(625, 627), match='lu'>
# <re.Match object; span=(627, 629), match='ke'>
# <re.Match object; span=(629, 631), match='.c'>
# <re.Match object; span=(631, 633), match='ie'>
# <re.Match object; span=(633, 635), match='rr'>
# <re.Match object; span=(635, 637), match='a@'>
# <re.Match object; span=(637, 639), match='br'>
# <re.Match object; span=(639, 641), match='ad'>
# <re.Match object; span=(641, 643), match='tk'>
# <re.Match object; span=(643, 645), match='e.'>
# <re.Match object; span=(645, 647), match='co'>
# <re.Match object; span=(647, 649), match='m\n'>
# <re.Match object; span=(649, 651), match='nr'>
# <re.Match object; span=(651, 653), match='om'>
# <re.Match object; span=(653, 655), match='ag'>
# <re.Match object; span=(655, 657), match='ue'>
# <re.Match object; span=(657, 659), match='ra'>
# <re.Match object; span=(659, 661), match='@y'>
# <re.Match object; span=(661, 663), match='ah'>
# <re.Match object; span=(663, 665), match='oo'>
# <re.Match object; span=(665, 667), match='.c'>
# <re.Match object; span=(667, 669), match='om'>
# <re.Match object; span=(669, 671), match='\nj'>
# <re.Match object; span=(671, 673), match='oh'>
# <re.Match object; span=(673, 675), match='n-'>
# <re.Match object; span=(675, 677), match='do'>
# <re.Match object; span=(677, 679), match='e@'>
# <re.Match object; span=(679, 681), match='gm'>
# <re.Match object; span=(681, 683), match='ai'>
# <re.Match object; span=(683, 685), match='l.'>
# <re.Match object; span=(685, 687), match='co'>
# <re.Match object; span=(687, 689), match='m\n'>
# <re.Match object; span=(689, 691), match='jo'>
# <re.Match object; span=(691, 693), match='hn'>
# <re.Match object; span=(693, 695), match='do'>
# <re.Match object; span=(700, 702), match='@g'>
# <re.Match object; span=(702, 704), match='ma'>
# <re.Match object; span=(704, 706), match='il'>
# <re.Match object; span=(706, 708), match='.c'>
# <re.Match object; span=(708, 710), match='om'>
# <re.Match object; span=(710, 712), match='\n\n'>

# %% [markdown]
# #### \w
# Word character (lowercase and uppercase letters, digits, or underscore)

# %%
mypattern = re.compile(r'\w\w\w')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(3, 6), match='Ale'>
# <re.Match object; span=(8, 11), match='Geo'>
# <re.Match object; span=(11, 14), match='rgi'>
# <re.Match object; span=(17, 20), match='Sha'>
# <re.Match object; span=(23, 26), match='Sul'>
# <re.Match object; span=(26, 29), match='eim'>
# <re.Match object; span=(32, 35), match='Lia'>
# <re.Match object; span=(37, 40), match='Oli'>
# <re.Match object; span=(40, 43), match='via'>
# <re.Match object; span=(44, 47), match='Noa'>
# <re.Match object; span=(49, 52), match='Emm'>
# <re.Match object; span=(54, 57), match='Oli'>
# <re.Match object; span=(57, 60), match='ver'>
# <re.Match object; span=(61, 64), match='Cha'>
# <re.Match object; span=(64, 67), match='rlo'>
# <re.Match object; span=(67, 70), match='tte'>
# <re.Match object; span=(71, 74), match='Eli'>
# <re.Match object; span=(74, 77), match='jah'>
# <re.Match object; span=(78, 81), match='Ame'>
# <re.Match object; span=(81, 84), match='lia'>
# <re.Match object; span=(85, 88), match='Jam'>
# <re.Match object; span=(91, 94), match='Ava'>
# <re.Match object; span=(95, 98), match='Wil'>
# <re.Match object; span=(98, 101), match='lia'>
# <re.Match object; span=(103, 106), match='Sop'>
# <re.Match object; span=(106, 109), match='hia'>
# <re.Match object; span=(110, 113), match='Ben'>
# <re.Match object; span=(113, 116), match='jam'>
# <re.Match object; span=(119, 122), match='Isa'>
# <re.Match object; span=(122, 125), match='bel'>
# <re.Match object; span=(128, 131), match='Luc'>
# <re.Match object; span=(134, 137), match='Mia'>
# <re.Match object; span=(138, 141), match='Hen'>
# <re.Match object; span=(144, 147), match='Eve'>
# <re.Match object; span=(147, 150), match='lyn'>
# <re.Match object; span=(151, 154), match='The'>
# <re.Match object; span=(154, 157), match='odo'>
# <re.Match object; span=(160, 163), match='Har'>
# <re.Match object; span=(163, 166), match='per'>
# <re.Match object; span=(174, 177), match='201'>
# <re.Match object; span=(185, 188), match='201'>
# <re.Match object; span=(214, 217), match='201'>
# <re.Match object; span=(223, 226), match='201'>
# <re.Match object; span=(232, 235), match='201'>
# <re.Match object; span=(238, 241), match='202'>
# <re.Match object; span=(242, 245), match='555'>
# <re.Match object; span=(246, 249), match='016'>
# <re.Match object; span=(251, 254), match='201'>
# <re.Match object; span=(255, 258), match='555'>
# <re.Match object; span=(259, 262), match='017'>
# <re.Match object; span=(265, 268), match='202'>
# <re.Match object; span=(270, 273), match='555'>
# <re.Match object; span=(274, 277), match='012'>
# <re.Match object; span=(280, 283), match='201'>
# <re.Match object; span=(284, 287), match='555'>
# <re.Match object; span=(288, 291), match='017'>
# <re.Match object; span=(293, 296), match='202'>
# <re.Match object; span=(297, 300), match='555'>
# <re.Match object; span=(301, 304), match='019'>
# <re.Match object; span=(306, 309), match='900'>
# <re.Match object; span=(310, 313), match='555'>
# <re.Match object; span=(314, 317), match='016'>
# <re.Match object; span=(319, 322), match='800'>
# <re.Match object; span=(323, 326), match='555'>
# <re.Match object; span=(327, 330), match='017'>
# <re.Match object; span=(333, 336), match='900'>
# <re.Match object; span=(338, 341), match='555'>
# <re.Match object; span=(342, 345), match='012'>
# <re.Match object; span=(348, 351), match='800'>
# <re.Match object; span=(352, 355), match='555'>
# <re.Match object; span=(356, 359), match='017'>
# <re.Match object; span=(361, 364), match='900'>
# <re.Match object; span=(365, 368), match='555'>
# <re.Match object; span=(369, 372), match='019'>
# <re.Match object; span=(374, 377), match='800'>
# <re.Match object; span=(378, 381), match='555'>
# <re.Match object; span=(382, 385), match='019'>
# <re.Match object; span=(387, 390), match='800'>
# <re.Match object; span=(391, 394), match='555'>
# <re.Match object; span=(395, 398), match='015'>
# <re.Match object; span=(400, 403), match='201'>
# <re.Match object; span=(404, 407), match='555'>
# <re.Match object; span=(408, 411), match='019'>
# <re.Match object; span=(413, 416), match='201'>
# <re.Match object; span=(417, 420), match='555'>
# <re.Match object; span=(421, 424), match='015'>
# <re.Match object; span=(432, 435), match='Dar'>
# <re.Match object; span=(442, 445), match='Tso'>
# <re.Match object; span=(445, 448), match='lak'>
# <re.Match object; span=(451, 454), match='Pro'>
# <re.Match object; span=(457, 460), match='Car'>
# <re.Match object; span=(460, 463), match='tle'>
# <re.Match object; span=(463, 466), match='dge'>
# <re.Match object; span=(473, 476), match='Mrs'>
# <re.Match object; span=(477, 480), match='Rob'>
# <re.Match object; span=(480, 483), match='ins'>
# <re.Match object; span=(490, 493), match='Bea'>
# <re.Match object; span=(495, 498), match='Mis'>
# <re.Match object; span=(500, 503), match='Pig'>
# <re.Match object; span=(509, 512), match='Joh'>
# <re.Match object; span=(512, 515), match='nDo'>
# <re.Match object; span=(517, 520), match='gma'>
# <re.Match object; span=(523, 526), match='com'>
# <re.Match object; span=(527, 530), match='Joh'>
# <re.Match object; span=(530, 533), match='n_D'>
# <re.Match object; span=(536, 539), match='gma'>
# <re.Match object; span=(542, 545), match='com'>
# <re.Match object; span=(546, 549), match='Joh'>
# <re.Match object; span=(549, 552), match='nDo'>
# <re.Match object; span=(554, 557), match='fac'>
# <re.Match object; span=(557, 560), match='ebo'>
# <re.Match object; span=(563, 566), match='net'>
# <re.Match object; span=(567, 570), match='joh'>
# <re.Match object; span=(572, 575), match='doe'>
# <re.Match object; span=(576, 579), match='uch'>
# <re.Match object; span=(579, 582), match='ica'>
# <re.Match object; span=(585, 588), match='edu'>
# <re.Match object; span=(589, 592), match='sin'>
# <re.Match object; span=(592, 595), match='cer'>
# <re.Match object; span=(597, 600), match='jak'>
# <re.Match object; span=(600, 603), match='ubo'>
# <re.Match object; span=(603, 606), match='wsk'>
# <re.Match object; span=(608, 611), match='gut'>
# <re.Match object; span=(611, 614), match='kow'>
# <re.Match object; span=(614, 617), match='ski'>
# <re.Match object; span=(618, 621), match='com'>
# <re.Match object; span=(622, 625), match='ker'>
# <re.Match object; span=(625, 628), match='luk'>
# <re.Match object; span=(630, 633), match='cie'>
# <re.Match object; span=(633, 636), match='rra'>
# <re.Match object; span=(637, 640), match='bra'>
# <re.Match object; span=(640, 643), match='dtk'>
# <re.Match object; span=(645, 648), match='com'>
# <re.Match object; span=(649, 652), match='nro'>
# <re.Match object; span=(652, 655), match='mag'>
# <re.Match object; span=(655, 658), match='uer'>
# <re.Match object; span=(660, 663), match='yah'>
# <re.Match object; span=(666, 669), match='com'>
# <re.Match object; span=(670, 673), match='joh'>
# <re.Match object; span=(675, 678), match='doe'>
# <re.Match object; span=(679, 682), match='gma'>
# <re.Match object; span=(685, 688), match='com'>
# <re.Match object; span=(689, 692), match='joh'>
# <re.Match object; span=(692, 695), match='ndo'>
# <re.Match object; span=(695, 698), match='e19'>
# <re.Match object; span=(701, 704), match='gma'>
# <re.Match object; span=(707, 710), match='com'>

# %% [markdown]
# #### \W
# Not a word character

# %%
mypattern = re.compile(r'\W')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 2), match='\n'>
# <re.Match object; span=(2, 3), match='\n'>
# <re.Match object; span=(7, 8), match='\n'>
# <re.Match object; span=(16, 17), match='\n'>
# <re.Match object; span=(22, 23), match='\n'>
# <re.Match object; span=(31, 32), match='\n'>
# <re.Match object; span=(36, 37), match='\n'>
# <re.Match object; span=(43, 44), match='\n'>
# <re.Match object; span=(48, 49), match='\n'>
# <re.Match object; span=(53, 54), match='\n'>
# <re.Match object; span=(60, 61), match='\n'>
# <re.Match object; span=(70, 71), match='\n'>
# <re.Match object; span=(77, 78), match='\n'>
# <re.Match object; span=(84, 85), match='\n'>
# <re.Match object; span=(90, 91), match='\n'>
# <re.Match object; span=(94, 95), match='\n'>
# <re.Match object; span=(102, 103), match='\n'>
# <re.Match object; span=(109, 110), match='\n'>
# <re.Match object; span=(118, 119), match='\n'>
# <re.Match object; span=(127, 128), match='\n'>
# <re.Match object; span=(133, 134), match='\n'>
# <re.Match object; span=(137, 138), match='\n'>
# <re.Match object; span=(143, 144), match='\n'>
# <re.Match object; span=(150, 151), match='\n'>
# <re.Match object; span=(159, 160), match='\n'>
# <re.Match object; span=(166, 167), match='\n'>
# <re.Match object; span=(167, 168), match='\n'>
# <re.Match object; span=(170, 171), match='-'>
# <re.Match object; span=(173, 174), match='-'>
# <re.Match object; span=(178, 179), match='\n'>
# <re.Match object; span=(181, 182), match='-'>
# <re.Match object; span=(184, 185), match='-'>
# <re.Match object; span=(189, 190), match='\n'>
# <re.Match object; span=(192, 193), match='/'>
# <re.Match object; span=(195, 196), match='/'>
# <re.Match object; span=(198, 199), match='\n'>
# <re.Match object; span=(201, 202), match='.'>
# <re.Match object; span=(204, 205), match='.'>
# <re.Match object; span=(207, 208), match='\n'>
# <re.Match object; span=(210, 211), match='.'>
# <re.Match object; span=(213, 214), match='.'>
# <re.Match object; span=(218, 219), match='\n'>
# <re.Match object; span=(220, 221), match='.'>
# <re.Match object; span=(222, 223), match='.'>
# <re.Match object; span=(227, 228), match='\n'>
# <re.Match object; span=(229, 230), match='.'>
# <re.Match object; span=(231, 232), match='.'>
# <re.Match object; span=(236, 237), match='\n'>
# <re.Match object; span=(237, 238), match='\n'>
# <re.Match object; span=(241, 242), match='-'>
# <re.Match object; span=(245, 246), match='-'>
# <re.Match object; span=(250, 251), match='\n'>
# <re.Match object; span=(254, 255), match='*'>
# <re.Match object; span=(258, 259), match='*'>
# <re.Match object; span=(263, 264), match='\n'>
# <re.Match object; span=(264, 265), match='('>
# <re.Match object; span=(268, 269), match=')'>
# <re.Match object; span=(269, 270), match=' '>
# <re.Match object; span=(273, 274), match='-'>
# <re.Match object; span=(278, 279), match='\n'>
# <re.Match object; span=(279, 280), match='('>
# <re.Match object; span=(283, 284), match=')'>
# <re.Match object; span=(287, 288), match='-'>
# <re.Match object; span=(292, 293), match='\n'>
# <re.Match object; span=(296, 297), match=' '>
# <re.Match object; span=(300, 301), match=' '>
# <re.Match object; span=(305, 306), match='\n'>
# <re.Match object; span=(309, 310), match='-'>
# <re.Match object; span=(313, 314), match='-'>
# <re.Match object; span=(318, 319), match='\n'>
# <re.Match object; span=(322, 323), match='*'>
# <re.Match object; span=(326, 327), match='*'>
# <re.Match object; span=(331, 332), match='\n'>
# <re.Match object; span=(332, 333), match='('>
# <re.Match object; span=(336, 337), match=')'>
# <re.Match object; span=(337, 338), match=' '>
# <re.Match object; span=(341, 342), match='-'>
# <re.Match object; span=(346, 347), match='\n'>
# <re.Match object; span=(347, 348), match='('>
# <re.Match object; span=(351, 352), match=')'>
# <re.Match object; span=(355, 356), match='-'>
# <re.Match object; span=(360, 361), match='\n'>
# <re.Match object; span=(364, 365), match=' '>
# <re.Match object; span=(368, 369), match=' '>
# <re.Match object; span=(373, 374), match='\n'>
# <re.Match object; span=(377, 378), match='.'>
# <re.Match object; span=(381, 382), match='.'>
# <re.Match object; span=(386, 387), match='\n'>
# <re.Match object; span=(390, 391), match='.'>
# <re.Match object; span=(394, 395), match='.'>
# <re.Match object; span=(399, 400), match='\n'>
# <re.Match object; span=(403, 404), match='.'>
# <re.Match object; span=(407, 408), match='.'>
# <re.Match object; span=(412, 413), match='\n'>
# <re.Match object; span=(416, 417), match='.'>
# <re.Match object; span=(420, 421), match='.'>
# <re.Match object; span=(425, 426), match='\n'>
# <re.Match object; span=(426, 427), match='\n'>
# <re.Match object; span=(427, 428), match='\n'>
# <re.Match object; span=(430, 431), match='.'>
# <re.Match object; span=(431, 432), match=' '>
# <re.Match object; span=(437, 438), match='\n'>
# <re.Match object; span=(440, 441), match='.'>
# <re.Match object; span=(441, 442), match=' '>
# <re.Match object; span=(450, 451), match='\n'>
# <re.Match object; span=(455, 456), match='.'>
# <re.Match object; span=(456, 457), match=' '>
# <re.Match object; span=(466, 467), match='\n'>
# <re.Match object; span=(469, 470), match='.'>
# <re.Match object; span=(470, 471), match=' '>
# <re.Match object; span=(472, 473), match='\n'>
# <re.Match object; span=(476, 477), match=' '>
# <re.Match object; span=(485, 486), match='\n'>
# <re.Match object; span=(488, 489), match='.'>
# <re.Match object; span=(489, 490), match=' '>
# <re.Match object; span=(494, 495), match='\n'>
# <re.Match object; span=(499, 500), match=' '>
# <re.Match object; span=(505, 506), match=' '>
# <re.Match object; span=(506, 507), match='\n'>
# <re.Match object; span=(507, 508), match='\n'>
# <re.Match object; span=(508, 509), match='\n'>
# <re.Match object; span=(516, 517), match='@'>
# <re.Match object; span=(522, 523), match='.'>
# <re.Match object; span=(526, 527), match='\n'>
# <re.Match object; span=(535, 536), match='@'>
# <re.Match object; span=(541, 542), match='.'>
# <re.Match object; span=(545, 546), match='\n'>
# <re.Match object; span=(553, 554), match='@'>
# <re.Match object; span=(562, 563), match='.'>
# <re.Match object; span=(566, 567), match='\n'>
# <re.Match object; span=(571, 572), match='.'>
# <re.Match object; span=(575, 576), match='@'>
# <re.Match object; span=(584, 585), match='.'>
# <re.Match object; span=(588, 589), match='\n'>
# <re.Match object; span=(596, 597), match='.'>
# <re.Match object; span=(607, 608), match='@'>
# <re.Match object; span=(617, 618), match='.'>
# <re.Match object; span=(621, 622), match='\n'>
# <re.Match object; span=(629, 630), match='.'>
# <re.Match object; span=(636, 637), match='@'>
# <re.Match object; span=(644, 645), match='.'>
# <re.Match object; span=(648, 649), match='\n'>
# <re.Match object; span=(659, 660), match='@'>
# <re.Match object; span=(665, 666), match='.'>
# <re.Match object; span=(669, 670), match='\n'>
# <re.Match object; span=(674, 675), match='-'>
# <re.Match object; span=(678, 679), match='@'>
# <re.Match object; span=(684, 685), match='.'>
# <re.Match object; span=(688, 689), match='\n'>
# <re.Match object; span=(700, 701), match='@'>
# <re.Match object; span=(706, 707), match='.'>
# <re.Match object; span=(710, 711), match='\n'>
# <re.Match object; span=(711, 712), match='\n'>

# %% [markdown]
# #### \s
# Whitespace (space, tab, newline)

# %%
mypattern = re.compile(r'\s')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 2), match='\n'>
# <re.Match object; span=(2, 3), match='\n'>
# <re.Match object; span=(7, 8), match='\n'>
# <re.Match object; span=(16, 17), match='\n'>
# <re.Match object; span=(22, 23), match='\n'>
# <re.Match object; span=(31, 32), match='\n'>
# <re.Match object; span=(36, 37), match='\n'>
# <re.Match object; span=(43, 44), match='\n'>
# <re.Match object; span=(48, 49), match='\n'>
# <re.Match object; span=(53, 54), match='\n'>
# <re.Match object; span=(60, 61), match='\n'>
# <re.Match object; span=(70, 71), match='\n'>
# <re.Match object; span=(77, 78), match='\n'>
# <re.Match object; span=(84, 85), match='\n'>
# <re.Match object; span=(90, 91), match='\n'>
# <re.Match object; span=(94, 95), match='\n'>
# <re.Match object; span=(102, 103), match='\n'>
# <re.Match object; span=(109, 110), match='\n'>
# <re.Match object; span=(118, 119), match='\n'>
# <re.Match object; span=(127, 128), match='\n'>
# <re.Match object; span=(133, 134), match='\n'>
# <re.Match object; span=(137, 138), match='\n'>
# <re.Match object; span=(143, 144), match='\n'>
# <re.Match object; span=(150, 151), match='\n'>
# <re.Match object; span=(159, 160), match='\n'>
# <re.Match object; span=(166, 167), match='\n'>
# <re.Match object; span=(167, 168), match='\n'>
# <re.Match object; span=(178, 179), match='\n'>
# <re.Match object; span=(189, 190), match='\n'>
# <re.Match object; span=(198, 199), match='\n'>
# <re.Match object; span=(207, 208), match='\n'>
# <re.Match object; span=(218, 219), match='\n'>
# <re.Match object; span=(227, 228), match='\n'>
# <re.Match object; span=(236, 237), match='\n'>
# <re.Match object; span=(237, 238), match='\n'>
# <re.Match object; span=(250, 251), match='\n'>
# <re.Match object; span=(263, 264), match='\n'>
# <re.Match object; span=(269, 270), match=' '>
# <re.Match object; span=(278, 279), match='\n'>
# <re.Match object; span=(292, 293), match='\n'>
# <re.Match object; span=(296, 297), match=' '>
# <re.Match object; span=(300, 301), match=' '>
# <re.Match object; span=(305, 306), match='\n'>
# <re.Match object; span=(318, 319), match='\n'>
# <re.Match object; span=(331, 332), match='\n'>
# <re.Match object; span=(337, 338), match=' '>
# <re.Match object; span=(346, 347), match='\n'>
# <re.Match object; span=(360, 361), match='\n'>
# <re.Match object; span=(364, 365), match=' '>
# <re.Match object; span=(368, 369), match=' '>
# <re.Match object; span=(373, 374), match='\n'>
# <re.Match object; span=(386, 387), match='\n'>
# <re.Match object; span=(399, 400), match='\n'>
# <re.Match object; span=(412, 413), match='\n'>
# <re.Match object; span=(425, 426), match='\n'>
# <re.Match object; span=(426, 427), match='\n'>
# <re.Match object; span=(427, 428), match='\n'>
# <re.Match object; span=(431, 432), match=' '>
# <re.Match object; span=(437, 438), match='\n'>
# <re.Match object; span=(441, 442), match=' '>
# <re.Match object; span=(450, 451), match='\n'>
# <re.Match object; span=(456, 457), match=' '>
# <re.Match object; span=(466, 467), match='\n'>
# <re.Match object; span=(470, 471), match=' '>
# <re.Match object; span=(472, 473), match='\n'>
# <re.Match object; span=(476, 477), match=' '>
# <re.Match object; span=(485, 486), match='\n'>
# <re.Match object; span=(489, 490), match=' '>
# <re.Match object; span=(494, 495), match='\n'>
# <re.Match object; span=(499, 500), match=' '>
# <re.Match object; span=(505, 506), match=' '>
# <re.Match object; span=(506, 507), match='\n'>
# <re.Match object; span=(507, 508), match='\n'>
# <re.Match object; span=(508, 509), match='\n'>
# <re.Match object; span=(526, 527), match='\n'>
# <re.Match object; span=(545, 546), match='\n'>
# <re.Match object; span=(566, 567), match='\n'>
# <re.Match object; span=(588, 589), match='\n'>
# <re.Match object; span=(621, 622), match='\n'>
# <re.Match object; span=(648, 649), match='\n'>
# <re.Match object; span=(669, 670), match='\n'>
# <re.Match object; span=(688, 689), match='\n'>
# <re.Match object; span=(710, 711), match='\n'>
# <re.Match object; span=(711, 712), match='\n'>

# %% [markdown]
# #### \S
# Not whitespace

# %%
mypattern = re.compile(r'\S')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(3, 4), match='A'>
# <re.Match object; span=(4, 5), match='l'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='x'>
# <re.Match object; span=(8, 9), match='G'>
# <re.Match object; span=(9, 10), match='e'>
# <re.Match object; span=(10, 11), match='o'>
# <re.Match object; span=(11, 12), match='r'>
# <re.Match object; span=(12, 13), match='g'>
# <re.Match object; span=(13, 14), match='i'>
# <re.Match object; span=(14, 15), match='o'>
# <re.Match object; span=(15, 16), match='s'>
# <re.Match object; span=(17, 18), match='S'>
# <re.Match object; span=(18, 19), match='h'>
# <re.Match object; span=(19, 20), match='a'>
# <re.Match object; span=(20, 21), match='m'>
# <re.Match object; span=(21, 22), match='a'>
# <re.Match object; span=(23, 24), match='S'>
# <re.Match object; span=(24, 25), match='u'>
# <re.Match object; span=(25, 26), match='l'>
# <re.Match object; span=(26, 27), match='e'>
# <re.Match object; span=(27, 28), match='i'>
# <re.Match object; span=(28, 29), match='m'>
# <re.Match object; span=(29, 30), match='a'>
# <re.Match object; span=(30, 31), match='n'>
# <re.Match object; span=(32, 33), match='L'>
# <re.Match object; span=(33, 34), match='i'>
# <re.Match object; span=(34, 35), match='a'>
# <re.Match object; span=(35, 36), match='m'>
# <re.Match object; span=(37, 38), match='O'>
# <re.Match object; span=(38, 39), match='l'>
# <re.Match object; span=(39, 40), match='i'>
# <re.Match object; span=(40, 41), match='v'>
# <re.Match object; span=(41, 42), match='i'>
# <re.Match object; span=(42, 43), match='a'>
# <re.Match object; span=(44, 45), match='N'>
# <re.Match object; span=(45, 46), match='o'>
# <re.Match object; span=(46, 47), match='a'>
# <re.Match object; span=(47, 48), match='h'>
# <re.Match object; span=(49, 50), match='E'>
# <re.Match object; span=(50, 51), match='m'>
# <re.Match object; span=(51, 52), match='m'>
# <re.Match object; span=(52, 53), match='a'>
# <re.Match object; span=(54, 55), match='O'>
# <re.Match object; span=(55, 56), match='l'>
# <re.Match object; span=(56, 57), match='i'>
# <re.Match object; span=(57, 58), match='v'>
# <re.Match object; span=(58, 59), match='e'>
# <re.Match object; span=(59, 60), match='r'>
# <re.Match object; span=(61, 62), match='C'>
# <re.Match object; span=(62, 63), match='h'>
# <re.Match object; span=(63, 64), match='a'>
# <re.Match object; span=(64, 65), match='r'>
# <re.Match object; span=(65, 66), match='l'>
# <re.Match object; span=(66, 67), match='o'>
# <re.Match object; span=(67, 68), match='t'>
# <re.Match object; span=(68, 69), match='t'>
# <re.Match object; span=(69, 70), match='e'>
# <re.Match object; span=(71, 72), match='E'>
# <re.Match object; span=(72, 73), match='l'>
# <re.Match object; span=(73, 74), match='i'>
# <re.Match object; span=(74, 75), match='j'>
# <re.Match object; span=(75, 76), match='a'>
# <re.Match object; span=(76, 77), match='h'>
# <re.Match object; span=(78, 79), match='A'>
# <re.Match object; span=(79, 80), match='m'>
# <re.Match object; span=(80, 81), match='e'>
# <re.Match object; span=(81, 82), match='l'>
# <re.Match object; span=(82, 83), match='i'>
# <re.Match object; span=(83, 84), match='a'>
# <re.Match object; span=(85, 86), match='J'>
# <re.Match object; span=(86, 87), match='a'>
# <re.Match object; span=(87, 88), match='m'>
# <re.Match object; span=(88, 89), match='e'>
# <re.Match object; span=(89, 90), match='s'>
# <re.Match object; span=(91, 92), match='A'>
# <re.Match object; span=(92, 93), match='v'>
# <re.Match object; span=(93, 94), match='a'>
# <re.Match object; span=(95, 96), match='W'>
# <re.Match object; span=(96, 97), match='i'>
# <re.Match object; span=(97, 98), match='l'>
# <re.Match object; span=(98, 99), match='l'>
# <re.Match object; span=(99, 100), match='i'>
# <re.Match object; span=(100, 101), match='a'>
# <re.Match object; span=(101, 102), match='m'>
# <re.Match object; span=(103, 104), match='S'>
# <re.Match object; span=(104, 105), match='o'>
# <re.Match object; span=(105, 106), match='p'>
# <re.Match object; span=(106, 107), match='h'>
# <re.Match object; span=(107, 108), match='i'>
# <re.Match object; span=(108, 109), match='a'>
# <re.Match object; span=(110, 111), match='B'>
# <re.Match object; span=(111, 112), match='e'>
# <re.Match object; span=(112, 113), match='n'>
# <re.Match object; span=(113, 114), match='j'>
# <re.Match object; span=(114, 115), match='a'>
# <re.Match object; span=(115, 116), match='m'>
# <re.Match object; span=(116, 117), match='i'>
# <re.Match object; span=(117, 118), match='n'>
# <re.Match object; span=(119, 120), match='I'>
# <re.Match object; span=(120, 121), match='s'>
# <re.Match object; span=(121, 122), match='a'>
# <re.Match object; span=(122, 123), match='b'>
# <re.Match object; span=(123, 124), match='e'>
# <re.Match object; span=(124, 125), match='l'>
# <re.Match object; span=(125, 126), match='l'>
# <re.Match object; span=(126, 127), match='a'>
# <re.Match object; span=(128, 129), match='L'>
# <re.Match object; span=(129, 130), match='u'>
# <re.Match object; span=(130, 131), match='c'>
# <re.Match object; span=(131, 132), match='a'>
# <re.Match object; span=(132, 133), match='s'>
# <re.Match object; span=(134, 135), match='M'>
# <re.Match object; span=(135, 136), match='i'>
# <re.Match object; span=(136, 137), match='a'>
# <re.Match object; span=(138, 139), match='H'>
# <re.Match object; span=(139, 140), match='e'>
# <re.Match object; span=(140, 141), match='n'>
# <re.Match object; span=(141, 142), match='r'>
# <re.Match object; span=(142, 143), match='y'>
# <re.Match object; span=(144, 145), match='E'>
# <re.Match object; span=(145, 146), match='v'>
# <re.Match object; span=(146, 147), match='e'>
# <re.Match object; span=(147, 148), match='l'>
# <re.Match object; span=(148, 149), match='y'>
# <re.Match object; span=(149, 150), match='n'>
# <re.Match object; span=(151, 152), match='T'>
# <re.Match object; span=(152, 153), match='h'>
# <re.Match object; span=(153, 154), match='e'>
# <re.Match object; span=(154, 155), match='o'>
# <re.Match object; span=(155, 156), match='d'>
# <re.Match object; span=(156, 157), match='o'>
# <re.Match object; span=(157, 158), match='r'>
# <re.Match object; span=(158, 159), match='e'>
# <re.Match object; span=(160, 161), match='H'>
# <re.Match object; span=(161, 162), match='a'>
# <re.Match object; span=(162, 163), match='r'>
# <re.Match object; span=(163, 164), match='p'>
# <re.Match object; span=(164, 165), match='e'>
# <re.Match object; span=(165, 166), match='r'>
# <re.Match object; span=(168, 169), match='0'>
# <re.Match object; span=(169, 170), match='8'>
# <re.Match object; span=(170, 171), match='-'>
# <re.Match object; span=(171, 172), match='1'>
# <re.Match object; span=(172, 173), match='2'>
# <re.Match object; span=(173, 174), match='-'>
# <re.Match object; span=(174, 175), match='2'>
# <re.Match object; span=(175, 176), match='0'>
# <re.Match object; span=(176, 177), match='1'>
# <re.Match object; span=(177, 178), match='2'>
# <re.Match object; span=(179, 180), match='0'>
# <re.Match object; span=(180, 181), match='6'>
# <re.Match object; span=(181, 182), match='-'>
# <re.Match object; span=(182, 183), match='0'>
# <re.Match object; span=(183, 184), match='7'>
# <re.Match object; span=(184, 185), match='-'>
# <re.Match object; span=(185, 186), match='2'>
# <re.Match object; span=(186, 187), match='0'>
# <re.Match object; span=(187, 188), match='1'>
# <re.Match object; span=(188, 189), match='5'>
# <re.Match object; span=(190, 191), match='0'>
# <re.Match object; span=(191, 192), match='8'>
# <re.Match object; span=(192, 193), match='/'>
# <re.Match object; span=(193, 194), match='0'>
# <re.Match object; span=(194, 195), match='8'>
# <re.Match object; span=(195, 196), match='/'>
# <re.Match object; span=(196, 197), match='0'>
# <re.Match object; span=(197, 198), match='8'>
# <re.Match object; span=(199, 200), match='0'>
# <re.Match object; span=(200, 201), match='4'>
# <re.Match object; span=(201, 202), match='.'>
# <re.Match object; span=(202, 203), match='0'>
# <re.Match object; span=(203, 204), match='8'>
# <re.Match object; span=(204, 205), match='.'>
# <re.Match object; span=(205, 206), match='0'>
# <re.Match object; span=(206, 207), match='8'>
# <re.Match object; span=(208, 209), match='0'>
# <re.Match object; span=(209, 210), match='9'>
# <re.Match object; span=(210, 211), match='.'>
# <re.Match object; span=(211, 212), match='0'>
# <re.Match object; span=(212, 213), match='9'>
# <re.Match object; span=(213, 214), match='.'>
# <re.Match object; span=(214, 215), match='2'>
# <re.Match object; span=(215, 216), match='0'>
# <re.Match object; span=(216, 217), match='1'>
# <re.Match object; span=(217, 218), match='9'>
# <re.Match object; span=(219, 220), match='9'>
# <re.Match object; span=(220, 221), match='.'>
# <re.Match object; span=(221, 222), match='9'>
# <re.Match object; span=(222, 223), match='.'>
# <re.Match object; span=(223, 224), match='2'>
# <re.Match object; span=(224, 225), match='0'>
# <re.Match object; span=(225, 226), match='1'>
# <re.Match object; span=(226, 227), match='9'>
# <re.Match object; span=(228, 229), match='8'>
# <re.Match object; span=(229, 230), match='.'>
# <re.Match object; span=(230, 231), match='9'>
# <re.Match object; span=(231, 232), match='.'>
# <re.Match object; span=(232, 233), match='2'>
# <re.Match object; span=(233, 234), match='0'>
# <re.Match object; span=(234, 235), match='1'>
# <re.Match object; span=(235, 236), match='9'>
# <re.Match object; span=(238, 239), match='2'>
# <re.Match object; span=(239, 240), match='0'>
# <re.Match object; span=(240, 241), match='2'>
# <re.Match object; span=(241, 242), match='-'>
# <re.Match object; span=(242, 243), match='5'>
# <re.Match object; span=(243, 244), match='5'>
# <re.Match object; span=(244, 245), match='5'>
# <re.Match object; span=(245, 246), match='-'>
# <re.Match object; span=(246, 247), match='0'>
# <re.Match object; span=(247, 248), match='1'>
# <re.Match object; span=(248, 249), match='6'>
# <re.Match object; span=(249, 250), match='6'>
# <re.Match object; span=(251, 252), match='2'>
# <re.Match object; span=(252, 253), match='0'>
# <re.Match object; span=(253, 254), match='1'>
# <re.Match object; span=(254, 255), match='*'>
# <re.Match object; span=(255, 256), match='5'>
# <re.Match object; span=(256, 257), match='5'>
# <re.Match object; span=(257, 258), match='5'>
# <re.Match object; span=(258, 259), match='*'>
# <re.Match object; span=(259, 260), match='0'>
# <re.Match object; span=(260, 261), match='1'>
# <re.Match object; span=(261, 262), match='7'>
# <re.Match object; span=(262, 263), match='7'>
# <re.Match object; span=(264, 265), match='('>
# <re.Match object; span=(265, 266), match='2'>
# <re.Match object; span=(266, 267), match='0'>
# <re.Match object; span=(267, 268), match='2'>
# <re.Match object; span=(268, 269), match=')'>
# <re.Match object; span=(270, 271), match='5'>
# <re.Match object; span=(271, 272), match='5'>
# <re.Match object; span=(272, 273), match='5'>
# <re.Match object; span=(273, 274), match='-'>
# <re.Match object; span=(274, 275), match='0'>
# <re.Match object; span=(275, 276), match='1'>
# <re.Match object; span=(276, 277), match='2'>
# <re.Match object; span=(277, 278), match='8'>
# <re.Match object; span=(279, 280), match='('>
# <re.Match object; span=(280, 281), match='2'>
# <re.Match object; span=(281, 282), match='0'>
# <re.Match object; span=(282, 283), match='1'>
# <re.Match object; span=(283, 284), match=')'>
# <re.Match object; span=(284, 285), match='5'>
# <re.Match object; span=(285, 286), match='5'>
# <re.Match object; span=(286, 287), match='5'>
# <re.Match object; span=(287, 288), match='-'>
# <re.Match object; span=(288, 289), match='0'>
# <re.Match object; span=(289, 290), match='1'>
# <re.Match object; span=(290, 291), match='7'>
# <re.Match object; span=(291, 292), match='8'>
# <re.Match object; span=(293, 294), match='2'>
# <re.Match object; span=(294, 295), match='0'>
# <re.Match object; span=(295, 296), match='2'>
# <re.Match object; span=(297, 298), match='5'>
# <re.Match object; span=(298, 299), match='5'>
# <re.Match object; span=(299, 300), match='5'>
# <re.Match object; span=(301, 302), match='0'>
# <re.Match object; span=(302, 303), match='1'>
# <re.Match object; span=(303, 304), match='9'>
# <re.Match object; span=(304, 305), match='8'>
# <re.Match object; span=(306, 307), match='9'>
# <re.Match object; span=(307, 308), match='0'>
# <re.Match object; span=(308, 309), match='0'>
# <re.Match object; span=(309, 310), match='-'>
# <re.Match object; span=(310, 311), match='5'>
# <re.Match object; span=(311, 312), match='5'>
# <re.Match object; span=(312, 313), match='5'>
# <re.Match object; span=(313, 314), match='-'>
# <re.Match object; span=(314, 315), match='0'>
# <re.Match object; span=(315, 316), match='1'>
# <re.Match object; span=(316, 317), match='6'>
# <re.Match object; span=(317, 318), match='6'>
# <re.Match object; span=(319, 320), match='8'>
# <re.Match object; span=(320, 321), match='0'>
# <re.Match object; span=(321, 322), match='0'>
# <re.Match object; span=(322, 323), match='*'>
# <re.Match object; span=(323, 324), match='5'>
# <re.Match object; span=(324, 325), match='5'>
# <re.Match object; span=(325, 326), match='5'>
# <re.Match object; span=(326, 327), match='*'>
# <re.Match object; span=(327, 328), match='0'>
# <re.Match object; span=(328, 329), match='1'>
# <re.Match object; span=(329, 330), match='7'>
# <re.Match object; span=(330, 331), match='7'>
# <re.Match object; span=(332, 333), match='('>
# <re.Match object; span=(333, 334), match='9'>
# <re.Match object; span=(334, 335), match='0'>
# <re.Match object; span=(335, 336), match='0'>
# <re.Match object; span=(336, 337), match=')'>
# <re.Match object; span=(338, 339), match='5'>
# <re.Match object; span=(339, 340), match='5'>
# <re.Match object; span=(340, 341), match='5'>
# <re.Match object; span=(341, 342), match='-'>
# <re.Match object; span=(342, 343), match='0'>
# <re.Match object; span=(343, 344), match='1'>
# <re.Match object; span=(344, 345), match='2'>
# <re.Match object; span=(345, 346), match='8'>
# <re.Match object; span=(347, 348), match='('>
# <re.Match object; span=(348, 349), match='8'>
# <re.Match object; span=(349, 350), match='0'>
# <re.Match object; span=(350, 351), match='0'>
# <re.Match object; span=(351, 352), match=')'>
# <re.Match object; span=(352, 353), match='5'>
# <re.Match object; span=(353, 354), match='5'>
# <re.Match object; span=(354, 355), match='5'>
# <re.Match object; span=(355, 356), match='-'>
# <re.Match object; span=(356, 357), match='0'>
# <re.Match object; span=(357, 358), match='1'>
# <re.Match object; span=(358, 359), match='7'>
# <re.Match object; span=(359, 360), match='8'>
# <re.Match object; span=(361, 362), match='9'>
# <re.Match object; span=(362, 363), match='0'>
# <re.Match object; span=(363, 364), match='0'>
# <re.Match object; span=(365, 366), match='5'>
# <re.Match object; span=(366, 367), match='5'>
# <re.Match object; span=(367, 368), match='5'>
# <re.Match object; span=(369, 370), match='0'>
# <re.Match object; span=(370, 371), match='1'>
# <re.Match object; span=(371, 372), match='9'>
# <re.Match object; span=(372, 373), match='8'>
# <re.Match object; span=(374, 375), match='8'>
# <re.Match object; span=(375, 376), match='0'>
# <re.Match object; span=(376, 377), match='0'>
# <re.Match object; span=(377, 378), match='.'>
# <re.Match object; span=(378, 379), match='5'>
# <re.Match object; span=(379, 380), match='5'>
# <re.Match object; span=(380, 381), match='5'>
# <re.Match object; span=(381, 382), match='.'>
# <re.Match object; span=(382, 383), match='0'>
# <re.Match object; span=(383, 384), match='1'>
# <re.Match object; span=(384, 385), match='9'>
# <re.Match object; span=(385, 386), match='9'>
# <re.Match object; span=(387, 388), match='8'>
# <re.Match object; span=(388, 389), match='0'>
# <re.Match object; span=(389, 390), match='0'>
# <re.Match object; span=(390, 391), match='.'>
# <re.Match object; span=(391, 392), match='5'>
# <re.Match object; span=(392, 393), match='5'>
# <re.Match object; span=(393, 394), match='5'>
# <re.Match object; span=(394, 395), match='.'>
# <re.Match object; span=(395, 396), match='0'>
# <re.Match object; span=(396, 397), match='1'>
# <re.Match object; span=(397, 398), match='5'>
# <re.Match object; span=(398, 399), match='2'>
# <re.Match object; span=(400, 401), match='2'>
# <re.Match object; span=(401, 402), match='0'>
# <re.Match object; span=(402, 403), match='1'>
# <re.Match object; span=(403, 404), match='.'>
# <re.Match object; span=(404, 405), match='5'>
# <re.Match object; span=(405, 406), match='5'>
# <re.Match object; span=(406, 407), match='5'>
# <re.Match object; span=(407, 408), match='.'>
# <re.Match object; span=(408, 409), match='0'>
# <re.Match object; span=(409, 410), match='1'>
# <re.Match object; span=(410, 411), match='9'>
# <re.Match object; span=(411, 412), match='9'>
# <re.Match object; span=(413, 414), match='2'>
# <re.Match object; span=(414, 415), match='0'>
# <re.Match object; span=(415, 416), match='1'>
# <re.Match object; span=(416, 417), match='.'>
# <re.Match object; span=(417, 418), match='5'>
# <re.Match object; span=(418, 419), match='5'>
# <re.Match object; span=(419, 420), match='5'>
# <re.Match object; span=(420, 421), match='.'>
# <re.Match object; span=(421, 422), match='0'>
# <re.Match object; span=(422, 423), match='1'>
# <re.Match object; span=(423, 424), match='5'>
# <re.Match object; span=(424, 425), match='2'>
# <re.Match object; span=(428, 429), match='M'>
# <re.Match object; span=(429, 430), match='r'>
# <re.Match object; span=(430, 431), match='.'>
# <re.Match object; span=(432, 433), match='D'>
# <re.Match object; span=(433, 434), match='a'>
# <re.Match object; span=(434, 435), match='r'>
# <re.Match object; span=(435, 436), match='c'>
# <re.Match object; span=(436, 437), match='y'>
# <re.Match object; span=(438, 439), match='D'>
# <re.Match object; span=(439, 440), match='r'>
# <re.Match object; span=(440, 441), match='.'>
# <re.Match object; span=(442, 443), match='T'>
# <re.Match object; span=(443, 444), match='s'>
# <re.Match object; span=(444, 445), match='o'>
# <re.Match object; span=(445, 446), match='l'>
# <re.Match object; span=(446, 447), match='a'>
# <re.Match object; span=(447, 448), match='k'>
# <re.Match object; span=(448, 449), match='i'>
# <re.Match object; span=(449, 450), match='s'>
# <re.Match object; span=(451, 452), match='P'>
# <re.Match object; span=(452, 453), match='r'>
# <re.Match object; span=(453, 454), match='o'>
# <re.Match object; span=(454, 455), match='f'>
# <re.Match object; span=(455, 456), match='.'>
# <re.Match object; span=(457, 458), match='C'>
# <re.Match object; span=(458, 459), match='a'>
# <re.Match object; span=(459, 460), match='r'>
# <re.Match object; span=(460, 461), match='t'>
# <re.Match object; span=(461, 462), match='l'>
# <re.Match object; span=(462, 463), match='e'>
# <re.Match object; span=(463, 464), match='d'>
# <re.Match object; span=(464, 465), match='g'>
# <re.Match object; span=(465, 466), match='e'>
# <re.Match object; span=(467, 468), match='M'>
# <re.Match object; span=(468, 469), match='r'>
# <re.Match object; span=(469, 470), match='.'>
# <re.Match object; span=(471, 472), match='T'>
# <re.Match object; span=(473, 474), match='M'>
# <re.Match object; span=(474, 475), match='r'>
# <re.Match object; span=(475, 476), match='s'>
# <re.Match object; span=(477, 478), match='R'>
# <re.Match object; span=(478, 479), match='o'>
# <re.Match object; span=(479, 480), match='b'>
# <re.Match object; span=(480, 481), match='i'>
# <re.Match object; span=(481, 482), match='n'>
# <re.Match object; span=(482, 483), match='s'>
# <re.Match object; span=(483, 484), match='o'>
# <re.Match object; span=(484, 485), match='n'>
# <re.Match object; span=(486, 487), match='M'>
# <re.Match object; span=(487, 488), match='r'>
# <re.Match object; span=(488, 489), match='.'>
# <re.Match object; span=(490, 491), match='B'>
# <re.Match object; span=(491, 492), match='e'>
# <re.Match object; span=(492, 493), match='a'>
# <re.Match object; span=(493, 494), match='n'>
# <re.Match object; span=(495, 496), match='M'>
# <re.Match object; span=(496, 497), match='i'>
# <re.Match object; span=(497, 498), match='s'>
# <re.Match object; span=(498, 499), match='s'>
# <re.Match object; span=(500, 501), match='P'>
# <re.Match object; span=(501, 502), match='i'>
# <re.Match object; span=(502, 503), match='g'>
# <re.Match object; span=(503, 504), match='g'>
# <re.Match object; span=(504, 505), match='y'>
# <re.Match object; span=(509, 510), match='J'>
# <re.Match object; span=(510, 511), match='o'>
# <re.Match object; span=(511, 512), match='h'>
# <re.Match object; span=(512, 513), match='n'>
# <re.Match object; span=(513, 514), match='D'>
# <re.Match object; span=(514, 515), match='o'>
# <re.Match object; span=(515, 516), match='e'>
# <re.Match object; span=(516, 517), match='@'>
# <re.Match object; span=(517, 518), match='g'>
# <re.Match object; span=(518, 519), match='m'>
# <re.Match object; span=(519, 520), match='a'>
# <re.Match object; span=(520, 521), match='i'>
# <re.Match object; span=(521, 522), match='l'>
# <re.Match object; span=(522, 523), match='.'>
# <re.Match object; span=(523, 524), match='c'>
# <re.Match object; span=(524, 525), match='o'>
# <re.Match object; span=(525, 526), match='m'>
# <re.Match object; span=(527, 528), match='J'>
# <re.Match object; span=(528, 529), match='o'>
# <re.Match object; span=(529, 530), match='h'>
# <re.Match object; span=(530, 531), match='n'>
# <re.Match object; span=(531, 532), match='_'>
# <re.Match object; span=(532, 533), match='D'>
# <re.Match object; span=(533, 534), match='o'>
# <re.Match object; span=(534, 535), match='e'>
# <re.Match object; span=(535, 536), match='@'>
# <re.Match object; span=(536, 537), match='g'>
# <re.Match object; span=(537, 538), match='m'>
# <re.Match object; span=(538, 539), match='a'>
# <re.Match object; span=(539, 540), match='i'>
# <re.Match object; span=(540, 541), match='l'>
# <re.Match object; span=(541, 542), match='.'>
# <re.Match object; span=(542, 543), match='c'>
# <re.Match object; span=(543, 544), match='o'>
# <re.Match object; span=(544, 545), match='m'>
# <re.Match object; span=(546, 547), match='J'>
# <re.Match object; span=(547, 548), match='o'>
# <re.Match object; span=(548, 549), match='h'>
# <re.Match object; span=(549, 550), match='n'>
# <re.Match object; span=(550, 551), match='D'>
# <re.Match object; span=(551, 552), match='o'>
# <re.Match object; span=(552, 553), match='e'>
# <re.Match object; span=(553, 554), match='@'>
# <re.Match object; span=(554, 555), match='f'>
# <re.Match object; span=(555, 556), match='a'>
# <re.Match object; span=(556, 557), match='c'>
# <re.Match object; span=(557, 558), match='e'>
# <re.Match object; span=(558, 559), match='b'>
# <re.Match object; span=(559, 560), match='o'>
# <re.Match object; span=(560, 561), match='o'>
# <re.Match object; span=(561, 562), match='k'>
# <re.Match object; span=(562, 563), match='.'>
# <re.Match object; span=(563, 564), match='n'>
# <re.Match object; span=(564, 565), match='e'>
# <re.Match object; span=(565, 566), match='t'>
# <re.Match object; span=(567, 568), match='j'>
# <re.Match object; span=(568, 569), match='o'>
# <re.Match object; span=(569, 570), match='h'>
# <re.Match object; span=(570, 571), match='n'>
# <re.Match object; span=(571, 572), match='.'>
# <re.Match object; span=(572, 573), match='d'>
# <re.Match object; span=(573, 574), match='o'>
# <re.Match object; span=(574, 575), match='e'>
# <re.Match object; span=(575, 576), match='@'>
# <re.Match object; span=(576, 577), match='u'>
# <re.Match object; span=(577, 578), match='c'>
# <re.Match object; span=(578, 579), match='h'>
# <re.Match object; span=(579, 580), match='i'>
# <re.Match object; span=(580, 581), match='c'>
# <re.Match object; span=(581, 582), match='a'>
# <re.Match object; span=(582, 583), match='g'>
# <re.Match object; span=(583, 584), match='o'>
# <re.Match object; span=(584, 585), match='.'>
# <re.Match object; span=(585, 586), match='e'>
# <re.Match object; span=(586, 587), match='d'>
# <re.Match object; span=(587, 588), match='u'>
# <re.Match object; span=(589, 590), match='s'>
# <re.Match object; span=(590, 591), match='i'>
# <re.Match object; span=(591, 592), match='n'>
# <re.Match object; span=(592, 593), match='c'>
# <re.Match object; span=(593, 594), match='e'>
# <re.Match object; span=(594, 595), match='r'>
# <re.Match object; span=(595, 596), match='e'>
# <re.Match object; span=(596, 597), match='.'>
# <re.Match object; span=(597, 598), match='j'>
# <re.Match object; span=(598, 599), match='a'>
# <re.Match object; span=(599, 600), match='k'>
# <re.Match object; span=(600, 601), match='u'>
# <re.Match object; span=(601, 602), match='b'>
# <re.Match object; span=(602, 603), match='o'>
# <re.Match object; span=(603, 604), match='w'>
# <re.Match object; span=(604, 605), match='s'>
# <re.Match object; span=(605, 606), match='k'>
# <re.Match object; span=(606, 607), match='i'>
# <re.Match object; span=(607, 608), match='@'>
# <re.Match object; span=(608, 609), match='g'>
# <re.Match object; span=(609, 610), match='u'>
# <re.Match object; span=(610, 611), match='t'>
# <re.Match object; span=(611, 612), match='k'>
# <re.Match object; span=(612, 613), match='o'>
# <re.Match object; span=(613, 614), match='w'>
# <re.Match object; span=(614, 615), match='s'>
# <re.Match object; span=(615, 616), match='k'>
# <re.Match object; span=(616, 617), match='i'>
# <re.Match object; span=(617, 618), match='.'>
# <re.Match object; span=(618, 619), match='c'>
# <re.Match object; span=(619, 620), match='o'>
# <re.Match object; span=(620, 621), match='m'>
# <re.Match object; span=(622, 623), match='k'>
# <re.Match object; span=(623, 624), match='e'>
# <re.Match object; span=(624, 625), match='r'>
# <re.Match object; span=(625, 626), match='l'>
# <re.Match object; span=(626, 627), match='u'>
# <re.Match object; span=(627, 628), match='k'>
# <re.Match object; span=(628, 629), match='e'>
# <re.Match object; span=(629, 630), match='.'>
# <re.Match object; span=(630, 631), match='c'>
# <re.Match object; span=(631, 632), match='i'>
# <re.Match object; span=(632, 633), match='e'>
# <re.Match object; span=(633, 634), match='r'>
# <re.Match object; span=(634, 635), match='r'>
# <re.Match object; span=(635, 636), match='a'>
# <re.Match object; span=(636, 637), match='@'>
# <re.Match object; span=(637, 638), match='b'>
# <re.Match object; span=(638, 639), match='r'>
# <re.Match object; span=(639, 640), match='a'>
# <re.Match object; span=(640, 641), match='d'>
# <re.Match object; span=(641, 642), match='t'>
# <re.Match object; span=(642, 643), match='k'>
# <re.Match object; span=(643, 644), match='e'>
# <re.Match object; span=(644, 645), match='.'>
# <re.Match object; span=(645, 646), match='c'>
# <re.Match object; span=(646, 647), match='o'>
# <re.Match object; span=(647, 648), match='m'>
# <re.Match object; span=(649, 650), match='n'>
# <re.Match object; span=(650, 651), match='r'>
# <re.Match object; span=(651, 652), match='o'>
# <re.Match object; span=(652, 653), match='m'>
# <re.Match object; span=(653, 654), match='a'>
# <re.Match object; span=(654, 655), match='g'>
# <re.Match object; span=(655, 656), match='u'>
# <re.Match object; span=(656, 657), match='e'>
# <re.Match object; span=(657, 658), match='r'>
# <re.Match object; span=(658, 659), match='a'>
# <re.Match object; span=(659, 660), match='@'>
# <re.Match object; span=(660, 661), match='y'>
# <re.Match object; span=(661, 662), match='a'>
# <re.Match object; span=(662, 663), match='h'>
# <re.Match object; span=(663, 664), match='o'>
# <re.Match object; span=(664, 665), match='o'>
# <re.Match object; span=(665, 666), match='.'>
# <re.Match object; span=(666, 667), match='c'>
# <re.Match object; span=(667, 668), match='o'>
# <re.Match object; span=(668, 669), match='m'>
# <re.Match object; span=(670, 671), match='j'>
# <re.Match object; span=(671, 672), match='o'>
# <re.Match object; span=(672, 673), match='h'>
# <re.Match object; span=(673, 674), match='n'>
# <re.Match object; span=(674, 675), match='-'>
# <re.Match object; span=(675, 676), match='d'>
# <re.Match object; span=(676, 677), match='o'>
# <re.Match object; span=(677, 678), match='e'>
# <re.Match object; span=(678, 679), match='@'>
# <re.Match object; span=(679, 680), match='g'>
# <re.Match object; span=(680, 681), match='m'>
# <re.Match object; span=(681, 682), match='a'>
# <re.Match object; span=(682, 683), match='i'>
# <re.Match object; span=(683, 684), match='l'>
# <re.Match object; span=(684, 685), match='.'>
# <re.Match object; span=(685, 686), match='c'>
# <re.Match object; span=(686, 687), match='o'>
# <re.Match object; span=(687, 688), match='m'>
# <re.Match object; span=(689, 690), match='j'>
# <re.Match object; span=(690, 691), match='o'>
# <re.Match object; span=(691, 692), match='h'>
# <re.Match object; span=(692, 693), match='n'>
# <re.Match object; span=(693, 694), match='d'>
# <re.Match object; span=(694, 695), match='o'>
# <re.Match object; span=(695, 696), match='e'>
# <re.Match object; span=(696, 697), match='1'>
# <re.Match object; span=(697, 698), match='9'>
# <re.Match object; span=(698, 699), match='9'>
# <re.Match object; span=(699, 700), match='0'>
# <re.Match object; span=(700, 701), match='@'>
# <re.Match object; span=(701, 702), match='g'>
# <re.Match object; span=(702, 703), match='m'>
# <re.Match object; span=(703, 704), match='a'>
# <re.Match object; span=(704, 705), match='i'>
# <re.Match object; span=(705, 706), match='l'>
# <re.Match object; span=(706, 707), match='.'>
# <re.Match object; span=(707, 708), match='c'>
# <re.Match object; span=(708, 709), match='o'>
# <re.Match object; span=(709, 710), match='m'>
# <re.Match object; span=(712, 713), match='Z'>

# %% [markdown]
# ### Anchors and Boundaries
# They do not match a character but positions

# %% [markdown]
# #### \b
# Word boundary

# %%
mypattern = re.compile(r'\bA..')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(3, 6), match='Ale'>
# <re.Match object; span=(78, 81), match='Ame'>
# <re.Match object; span=(91, 94), match='Ava'>

# %% [markdown]
# #### \B
# Not a word boundary

# %% [markdown]
# #### ^
# Beginning of the string

# %%
mypattern = re.compile(r'^')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 0), match=''>

# %% [markdown]
# #### $
# End of the string

# %% [markdown]
# #### Phone numbers

# %%
mypattern = re.compile(r'\d\d\d.\d\d\d.\d\d\d\d')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(238, 250), match='202-555-0166'>
# <re.Match object; span=(251, 263), match='201*555*0177'>
# <re.Match object; span=(280, 292), match='201)555-0178'>
# <re.Match object; span=(293, 305), match='202 555 0198'>
# <re.Match object; span=(306, 318), match='900-555-0166'>
# <re.Match object; span=(319, 331), match='800*555*0177'>
# <re.Match object; span=(348, 360), match='800)555-0178'>
# <re.Match object; span=(361, 373), match='900 555 0198'>
# <re.Match object; span=(374, 386), match='800.555.0199'>
# <re.Match object; span=(387, 399), match='800.555.0152'>
# <re.Match object; span=(400, 412), match='201.555.0199'>
# <re.Match object; span=(413, 425), match='201.555.0152'>

# %% [markdown]
# #### Quantifiers

# %% [markdown]
# | Quantifier | Meaning |
# | ----------- | -----------
# | a? | Zero or one of a |
# | a* | Zero or more of a |
# | a+ | One or more of a |
# | [0-9]+ | One or more of 0-9 |
# | a{3} | Exactly 3 of a |
# | a{3,} | 3 or more of a |
# | a{3,6} | Between 3 and 6 of a |
# | a* | Greedy quantifier |
# | a*? | Lazy quantifier |
# | a*+ | Possessive quantifier |

# %%
sentence = """
coffe coffee please sir I need some more coffee please"
"""

# %%
[a-zA-Z]{1,3}
# Out:
#   Input In [63]
#     [a-zA-Z]{1,3}
#             ^
# SyntaxError: invalid syntax

# %%
quote = re.findall('co.*ee', sentence)
print(quote)

# %%
quote = re.findall('co.*?ee', sentence)
print(quote)

# %% [markdown]
# #### Simplify the above regex

# %%
mypattern = re.compile(r'\800.\d{3}.\d{4}.')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 mypattern = re.compile(r'\800.\d{3}.\d{4}.')
#       2 matches = mypattern.finditer(faketext)
#       3 for match in matches:
#
# File ~/opt/anaconda3/lib/python3.9/re.py:252, in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#
# File ~/opt/anaconda3/lib/python3.9/re.py:304, in _compile(pattern, flags)
#     302 if not sre_compile.isstring(pattern):
#     303     raise TypeError("first argument must be string or compiled pattern")
# --> 304 p = sre_compile.compile(pattern, flags)
#     305 if not (flags & DEBUG):
#     306     if len(_cache) >= _MAXCACHE:
#     307         # Drop the oldest item
#
# File ~/opt/anaconda3/lib/python3.9/sre_compile.py:764, in compile(p, flags)
#     762 if isstring(p):
#     763     pattern = p
# --> 764     p = sre_parse.parse(p, flags)
#     765 else:
#     766     pattern = None
#
# File ~/opt/anaconda3/lib/python3.9/sre_parse.py:950, in parse(str, flags, state)
#     947 state.str = str
#     949 try:
# --> 950     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     951 except Verbose:
#     952     # the VERBOSE flag was switched on inside the pattern.  to be
#     953     # on the safe side, we'll parse the whole thing again...
#     954     state = State()
#
# File ~/opt/anaconda3/lib/python3.9/sre_parse.py:443, in _parse_sub(source, state, verbose, nested)
#     441 start = source.tell()
#     442 while True:
# --> 443     itemsappend(_parse(source, state, verbose, nested + 1,
#     444                        not nested and not items))
#     445     if not sourcematch("|"):
#     446         break
#
# File ~/opt/anaconda3/lib/python3.9/sre_parse.py:525, in _parse(source, state, verbose, nested, first)
#     522         continue
#     524 if this[0] == "\\":
# --> 525     code = _escape(source, this, state)
#     526     subpatternappend(code)
#     528 elif this not in SPECIAL_CHARS:
#
# File ~/opt/anaconda3/lib/python3.9/sre_parse.py:423, in _escape(source, escape, state)
#     421         state.checklookbehindgroup(group, source)
#     422         return GROUPREF, group
# --> 423     raise source.error("invalid group reference %d" % group, len(escape) - 1)
#     424 if len(escape) == 2:
#     425     if c in ASCIILETTERS:
#
# error: invalid group reference 80 at position 1

# %% [markdown]
# #### Get all phone numbers

# %% [markdown]
# #### Get all phone numbers that begin with 800

# %%
mypattern = re.compile(r'800.\d{3}.\d{4}.')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)

# %% [markdown]
# #### -
# Range e.g., [1-5] or [a-z] or [A-Z]

# %% [markdown]
# #### ^-
# Not the range e.g., [^1-5] or [^a-z] or [^A-Z]

# %% [markdown]
# #### Get all phone numbers that begin with 800 or 900

# %% [markdown]
# #### Get all the prefixes with the attached names

# %%
mypattern = re.compile(r'(Mr|Ms|Mrs|Dr|Prof). [A-Z]\w*\b')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(428, 437), match='Mr. Darcy'>
# <re.Match object; span=(438, 450), match='Dr. Tsolakis'>
# <re.Match object; span=(451, 466), match='Prof. Cartledge'>
# <re.Match object; span=(467, 472), match='Mr. T'>
# <re.Match object; span=(473, 485), match='Mrs Robinson'>
# <re.Match object; span=(486, 494), match='Mr. Bean'>

# %% [markdown]
# #### Match the emails

# %%
mypattern = re.compile(r'[a-zA-Z0-9\-]+@[a-zA-Z0-9\-]+.[a-zA-Z0-9\-]+')
matches = mypattern.finditer(faketext)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(509, 526), match='JohnDoe@gmail.com'>
# <re.Match object; span=(532, 545), match='Doe@gmail.com'>
# <re.Match object; span=(546, 566), match='JohnDoe@facebook.net'>
# <re.Match object; span=(572, 588), match='doe@uchicago.edu'>
# <re.Match object; span=(597, 621), match='jakubowski@gutkowski.com'>
# <re.Match object; span=(630, 648), match='cierra@bradtke.com'>
# <re.Match object; span=(649, 669), match='nromaguera@yahoo.com'>
# <re.Match object; span=(670, 688), match='john-doe@gmail.com'>
# <re.Match object; span=(689, 710), match='johndoe1990@gmail.com'>

# %% [markdown]
# #### Replace

# %% [markdown]
# #### sub

# %%
dates = """08-12-2012
06-07-2015
08/08/08
04.08.08
09.09.2019
9.9.2019
8.9.2019"""

# %% [markdown]
# #### findall

# %% [markdown]
# #### search
# Returns the first match otherwise it returns None

# %% [markdown]
# #### Flags

# %% [markdown]
# #### Write a regex that finds all roman numberals and print only how many roman numerals exist in the string.
# | Roman | Value |
# | --- | --- |
# | I | 1 |
# | II | 2 |
# | III | 3 |
# | IV | 4 |
# | IX | 9 |
# | X | 10 |
# | L | 50 |
# | C | 100 |
# | D | 500 |
# | M | 1000 |

# %%
numbers = """
DCXXXIV
CXXXI
CCXXXI
DCXX
DXCIX
DCIV
DCLVII
CLXXXV
XVI
CV
MCCLXXIV
CMIX
DXXXI
DL
DXCI
CDLXXIX
DLXII
CMXLII
CDX
CLXXXVIII
CDV
CXCI
XLII
LXVI
DCCXLVI
CDLXXXVII
"""

# %%
numbers2 = "DCXXXIV, CXXXI, CCXXXI, DCXX, DXCIX, DCIV, DCLVII, CLXXXV, XVI, CV, MCCLXXIV, CMIX, DXXXI, DL, DXCI, CDLXXIX, DLXII, CMXLII, CDX, CLXXXVIII, CDV, CXCI, XLII, LXVI, DCCXLVI, CDLXXXVII"

# %%
numberpattern = re.findall(r'^M{0,4}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3}),$', numbers)
print(numberpattern)
# Out:
# []

# %%
mypattern = re.compile(r'^M{0,4}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3})$')
matches = mypattern.finditer(numbers)
for match in matches:
    print(match)

# %%
resultnumbers = re.finditer(r'^M{0,4}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3}),$', numbers2)
print(resultnumbers)
# Out:
# <callable_iterator object at 0x7fd300affcd0>

# %% [markdown]
# ----

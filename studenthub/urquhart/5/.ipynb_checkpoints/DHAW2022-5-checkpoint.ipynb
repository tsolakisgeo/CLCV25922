# %% [markdown]
# ## Lists

# %%
mylist = ['John', 'Maria', 'Ted', 'Nick', 'Albert', 'John', 'Catherine']

# %% [markdown]
# #### Add the name Jim to the list

# %%
mylist.append('Jim')
print(mylist)
# Out:
# ['John', 'Maria', 'Ted', 'Nick', 'Albert', 'John', 'Catherine', 'Georgios', 'Jim']

# %% [markdown]
# #### Insert the name Bod to the 2nd place in the list

# %%
mylist.append('Bod')
print(mylist)
# Out:
# ['John', 'Maria', 'Ted', 'Nick', 'Albert', 'John', 'Catherine', 'Georgios', 'Jim', 'Bod', 'Bod']

# %% [markdown]
# #### Remove Ted from the list

# %%
mylist.remove('Ted')
print(mylist)
# Out:
# ['John', 'Maria', 'Nick', 'Albert', 'John', 'Catherine', 'Georgios', 'Jim', 'Bod', 'Bod']

# %% [markdown]
# ---

# %% [markdown]
# ## Tuples

# %% [markdown]
# #### Make mylist a tuple

# %% [markdown]
# #### Change the first element in the tuple

# %% [markdown]
# __We have to create a new tuple as while lists are mutable, tuples are immutable.__

# %% [markdown]
# ---

# %% [markdown]
# ## Dictionaries

# %%
persons = {
    "first": "John",
    "last": "Smith",
    "email": "johnsmith@gmail.com"
}

# %%
print(persons)
# Out:
# {'first': 'John', 'last': 'Smith', 'email': 'johnsmith@gmail.com'}

# %% [markdown]
# #### Add more people

# %%
persons = {
    "first": ["John", "Bob"],
    "last": ["Smith", "Doe"],
    "email": ["johnsmith@gmail.com", "bobdoe@gmail.com"]
}
print(persons)
# Out:
# {'first': ['John', 'Bob'], 'last': ['Smith', 'Doe'], 'email': ['johnsmith@gmail.com', 'bobdoe@gmail.com']}

# %% [markdown]
# ### items, keys, values

# %%
persons.values()

for keys, values in persons.items():
    print(keys)
    for values in values:
        print(values)
    print('\n')
# Out:
# first
# John
# Bob
#
#
# last
# Smith
# Doe
#
#
# email
# johnsmith@gmail.com
# bobdoe@gmail.com

# %% [markdown]
# ---

# %% [markdown]
# ## Set

# %% [markdown]
# #### Make mylist a set

# %%
mylist.append('Georgios')
print(mylist)

myset = set(mylist)
print(myset)
# Out:
# ['John', 'Maria', 'Ted', 'Nick', 'Albert', 'John', 'Catherine', 'Georgios']
# {'Albert', 'John', 'Catherine', 'Ted', 'Nick', 'Georgios', 'Maria'}

# %% [markdown]
# #### Make mylist again a list

# %% [markdown]
# ---

# %% [markdown]
# ## Read and Write to files

# %% [markdown]
# ### Read

# %%
file = open("README.md","r")
f = file.read()
file.close()

print(f)
# Out:
# Homework repository for Class 5.

# %% [markdown]
# ### Write

# %%
with open("README.md", "r") as file:
    f = file.read()
print(f)
# Out:
# Homework repository for Class 5.

# %%
mytext = "This is a new text"
with open("mynewtext.txt", 'w', encoding='utf-8') as file:
    file.write(mytext)
# This opens up a few file with "This is a new text" written on it.

# %%
with open("mynewtext.txt", 'w', encoding='utf-8') as file:
    for i in mylist:
#         file.write(i)
#         file.write("%s\n" % 1)
#         file.write ("{0}\n".format(i))
        file.write(f"{i}\n")

# %% [markdown]
# ---

# %% [markdown]
# ## Pandas and CSV/EXCEL

# %% [markdown]
# #### Libraries - Imports

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/alexanderurquhart/opt/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/alexanderurquhart/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/alexanderurquhart/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/alexanderurquhart/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/alexanderurquhart/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd # This is a convention in Python community.

# %% [markdown]
# #### Read

# %% [markdown]
# Download the csv of [Roman Amphitheaters](https://github.com/roman-amphitheaters/roman-amphitheaters/blob/main/roman-amphitheaters.csv)

# %%
df = pd.read_csv('RomanStuff.csv') # df stands for dataframe, i.e., row and columns of data.
# File needs to be in same folder

# %%
df
# Out:
#                                  id                                  title  \
# 0           duraEuroposAmphitheater           Amphitheater at Dura Europos
# 1                 arlesAmphitheater                  Amphitheater at Arles
# 2                  lyonAmphitheater                   Amphitheater at Lyon
# 3                  ludusMagnusArena                     Ludus Magnus Arena
# 4           romeFlavianAmphitheater           Flavian Amphitheater at Rome
# ..                              ...                                    ...
# 263            avenchesAmphitheater               Amphitheater at Avenches
# 264             venafroAmphitheater                Amphitheater at Venafro
# 265  saintGeorgesDuBoisAmphitheater  Amphitheater at Saint-Georges-du-Bois
# 266              toledoAmphitheater                 Amphitheater at Toledo
# 267        kaiseraugustAmphitheater            Amphitheater at Kaiseraugst
#
#                      label        latintoponym  \
# 0                     Dura        Dura Europus
# 1                    Arles             Arelate
# 2                     Lyon            Lugdunum
# 3             Ludus Magnus        Ludus Magnus
# 4                Colosseum                 NaN
# ..                     ...                 ...
# 263               Avenches           Aventicum
# 264                Venafro            Venafrum
# 265  Saint-Georges-du-Bois                 NaN
# 266                 Toledo             Toletum
# 267            Kaiseraugst  Castrum Rauracense
#
#                                       pleiades  welchid  golvinid  \
# 0      https://pleiades.stoa.org/places/893989      NaN     129.0
# 1      https://pleiades.stoa.org/places/148217      NaN     154.0
# 2      https://pleiades.stoa.org/places/167717      NaN       NaN
# 3      https://pleiades.stoa.org/places/423025      NaN       NaN
# 4      https://pleiades.stoa.org/places/423025      NaN     152.0
# ..                                         ...      ...       ...
# 263    https://pleiades.stoa.org/places/177495      NaN     104.0
# 264    https://pleiades.stoa.org/places/433185      NaN      87.0
# 265                                        NaN      NaN     103.0
# 266    https://pleiades.stoa.org/places/266066      NaN       NaN
# 267  https://pleiades.stoa.org/places/81716458      NaN       NaN
#
#        buildingtype     chronogroup  secondcentury  ...    zotero  \
# 0      amphitheater         severan          False  ...  5ADZC245
# 1      amphitheater         flavian           True  ...  LD7NNHSG
# 2      amphitheater  second-century           True  ...       NaN
# 3    practice-arena        imperial          False  ...       NaN
# 4      amphitheater         flavian           True  ...  VKMRD8AT
# ..              ...             ...            ...  ...       ...
# 263    amphitheater  second-century           True  ...  LD7NNHSG
# 264    amphitheater        imperial           True  ...  HQ9QC3FS
# 265    amphitheater   first-century           True  ...  ZSJDWT3E
# 266    amphitheater        imperial           True  ...  9JJW3LUE
# 267    amphitheater  fourth-century          False  ...  AUHQAHQB
#
#     dimensionsunknown arenamajor arenaminor  extmajor  extminor  \
# 0               False       31.0       25.0      50.0      44.0
# 1               False       47.0       32.0     136.0     107.0
# 2               False       67.6       42.0     105.0       NaN
# 3               False        NaN        NaN       NaN       NaN
# 4               False       83.0       48.0     189.0     156.0
# ..                ...        ...        ...       ...       ...
# 263             False       51.0       39.0      99.0      87.0
# 264             False       60.0       35.0     110.0      85.0
# 265             False       54.0       30.0      65.0      50.0
# 266              True        NaN        NaN       NaN       NaN
# 267             False        NaN        NaN      50.0      40.0
#
#      exteriorheight  longitude   latitude  elevation
# 0               NaN  40.728926  34.749855        223
# 1               NaN   4.631111  43.677778         21
# 2               NaN   4.830556  45.770556        206
# 3               NaN  12.494913  41.889950         22
# 4              52.0  12.492269  41.890169         22
# ..              ...        ...        ...        ...
# 263             NaN   7.042646  46.880971        470
# 264             NaN  14.046835  41.482550        176
# 265             NaN  -0.749919  46.142723         39
# 266             NaN  -4.022888  39.865349        482
# 267             NaN   7.721596  47.540822        482
#
# [268 rows x 23 columns]

# %%
df.head()
# Out:
#                         id                         title         label  \
# 0  duraEuroposAmphitheater  Amphitheater at Dura Europos          Dura
# 1        arlesAmphitheater         Amphitheater at Arles         Arles
# 2         lyonAmphitheater          Amphitheater at Lyon          Lyon
# 3         ludusMagnusArena            Ludus Magnus Arena  Ludus Magnus
# 4  romeFlavianAmphitheater  Flavian Amphitheater at Rome     Colosseum
#
#    latintoponym                                 pleiades  welchid  golvinid  \
# 0  Dura Europus  https://pleiades.stoa.org/places/893989      NaN     129.0
# 1       Arelate  https://pleiades.stoa.org/places/148217      NaN     154.0
# 2      Lugdunum  https://pleiades.stoa.org/places/167717      NaN       NaN
# 3  Ludus Magnus  https://pleiades.stoa.org/places/423025      NaN       NaN
# 4           NaN  https://pleiades.stoa.org/places/423025      NaN     152.0
#
#      buildingtype     chronogroup  secondcentury  ...    zotero  \
# 0    amphitheater         severan          False  ...  5ADZC245
# 1    amphitheater         flavian           True  ...  LD7NNHSG
# 2    amphitheater  second-century           True  ...       NaN
# 3  practice-arena        imperial          False  ...       NaN
# 4    amphitheater         flavian           True  ...  VKMRD8AT
#
#   dimensionsunknown arenamajor arenaminor  extmajor  extminor  exteriorheight  \
# 0             False       31.0       25.0      50.0      44.0             NaN
# 1             False       47.0       32.0     136.0     107.0             NaN
# 2             False       67.6       42.0     105.0       NaN             NaN
# 3             False        NaN        NaN       NaN       NaN             NaN
# 4             False       83.0       48.0     189.0     156.0            52.0
#
#    longitude   latitude  elevation
# 0  40.728926  34.749855        223
# 1   4.631111  43.677778         21
# 2   4.830556  45.770556        206
# 3  12.494913  41.889950         22
# 4  12.492269  41.890169         22
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#                                  id                                  title  \
# 263            avenchesAmphitheater               Amphitheater at Avenches
# 264             venafroAmphitheater                Amphitheater at Venafro
# 265  saintGeorgesDuBoisAmphitheater  Amphitheater at Saint-Georges-du-Bois
# 266              toledoAmphitheater                 Amphitheater at Toledo
# 267        kaiseraugustAmphitheater            Amphitheater at Kaiseraugst
#
#                      label        latintoponym  \
# 263               Avenches           Aventicum
# 264                Venafro            Venafrum
# 265  Saint-Georges-du-Bois                 NaN
# 266                 Toledo             Toletum
# 267            Kaiseraugst  Castrum Rauracense
#
#                                       pleiades  welchid  golvinid  \
# 263    https://pleiades.stoa.org/places/177495      NaN     104.0
# 264    https://pleiades.stoa.org/places/433185      NaN      87.0
# 265                                        NaN      NaN     103.0
# 266    https://pleiades.stoa.org/places/266066      NaN       NaN
# 267  https://pleiades.stoa.org/places/81716458      NaN       NaN
#
#      buildingtype     chronogroup  secondcentury  ...    zotero  \
# 263  amphitheater  second-century           True  ...  LD7NNHSG
# 264  amphitheater        imperial           True  ...  HQ9QC3FS
# 265  amphitheater   first-century           True  ...  ZSJDWT3E
# 266  amphitheater        imperial           True  ...  9JJW3LUE
# 267  amphitheater  fourth-century          False  ...  AUHQAHQB
#
#     dimensionsunknown arenamajor arenaminor  extmajor  extminor  \
# 263             False       51.0       39.0      99.0      87.0
# 264             False       60.0       35.0     110.0      85.0
# 265             False       54.0       30.0      65.0      50.0
# 266              True        NaN        NaN       NaN       NaN
# 267             False        NaN        NaN      50.0      40.0
#
#      exteriorheight  longitude   latitude  elevation
# 263             NaN   7.042646  46.880971        470
# 264             NaN  14.046835  41.482550        176
# 265             NaN  -0.749919  46.142723         39
# 266             NaN  -4.022888  39.865349        482
# 267             NaN   7.721596  47.540822        482
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Data types in our csv

# %%
df.shape # notice that this is an attribute so no parentheses
# Out:
# (268, 23)

# %%
df.info() # notice that this is a methon, so we need parentheses
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 268 non-null    object
#  1   title              268 non-null    object
#  2   label              268 non-null    object
#  3   latintoponym       219 non-null    object
#  4   pleiades           267 non-null    object
#  5   welchid            18 non-null     float64
#  6   golvinid           134 non-null    float64
#  7   buildingtype       268 non-null    object
#  8   chronogroup        268 non-null    object
#  9   secondcentury      268 non-null    bool
#  10  capacity           135 non-null    float64
#  11  modcountry         268 non-null    object
#  12  romanregion        268 non-null    object
#  13  zotero             56 non-null     object
#  14  dimensionsunknown  268 non-null    bool
#  15  arenamajor         179 non-null    float64
#  16  arenaminor         175 non-null    float64
#  17  extmajor           214 non-null    float64
#  18  extminor           194 non-null    float64
#  19  exteriorheight     3 non-null      float64
#  20  longitude          268 non-null    float64
#  21  latitude           268 non-null    float64
#  22  elevation          268 non-null    int64
# dtypes: bool(2), float64(10), int64(1), object(10)
# memory usage: 44.6+ KB

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# ### Example: Shipwrecks Database

# %% [markdown]
# Download the [Shipwrecks Database](http://oxrep.classics.ox.ac.uk/docs/StraussShipwrecks.zip) for the [The Oxford Roman Economy Project](http://oxrep.classics.ox.ac.uk/).

# %%
df = pd.read_excel('StraussShipwrecks.xlsx')

# %%
df
# Out:
#       Wreck ID  Strauss ID                            Name Parker Number  Sea area  Country                           Region  Latitude  Longitude  Min depth  Max depth    Depth          Period         Dating  Earliest date  Latest date  Date range  Mid point of date range  Probability Place of origin Place of destination                                          Reference                                           Comments  Amphorae  Marble  Columns etc  Sarcophagi  Blocks Marble type                                        Other cargo          Hull remains Shipboard paraphernalia                                     Ship equipment  Estimated tonnage Amphora type
# 0            1         331                          Komiza           NaN  Adriatic  Croatia                       Vis Island  43.03333   16.08333       30.0       30.0      30m  Roman Imperial    C1st-2nd AD            1.0        200.0         NaN                      NaN          NaN           Egypt       Northern Italy  M. Jurišić, Ancient Shipwrecks of the Adriatic...  Completely looted site with sherds of Egyptian...      True   False        False       False   False         NaN                                                NaN                   NaN                     NaN                                                NaN                NaN          NaN
# 1            2         328                         Lokunji           NaN  Adriatic  Croatia                   Kvarner region  44.70000   14.28333        4.0       12.0      12m  Roman Imperial       C 1st AD            1.0        100.0         NaN                      NaN          NaN             Cos       Northern Italy  D. Vrsalović, Istraživanja i Zaštita Podmorški...                                                NaN      True   False        False       False   False         NaN                                                NaN                   NaN                     NaN                                                NaN                NaN          NaN
# 2            3         329                    Maharac Cape           NaN  Adriatic  Croatia                     Mljet island  42.73333   17.66666        3.0       20.0    3-20m  Roman Imperial       C 1st AD            1.0        100.0         NaN                      NaN          NaN          Rhodes       Northern Italy  D. Vrsalović, PhD thesis (unpublished; 1979), ...                                                NaN      True   False        False       False   False         NaN  Eastern coarse ware pottery of biconical dishe...                   NaN                     NaN                                                NaN                NaN          NaN
# 3            4         330                            Mlin           702  Adriatic  Croatia                    Split channel  43.45000   16.23333       25.0       40.0      40m  Roman Imperial   C 1st-2nd AD            1.0        200.0         NaN                      NaN          NaN          Aegean       Northern Italy  D. Vrsalović, Istraživanja i Zaštita Podmorški...  A heavily looted mixed cargo of Greek amphorae...      True   False        False       False   False         NaN                                                NaN  Remains of the hull.                     NaN  Two lead anchor stocks, though possibly not fr...                NaN          NaN
# 4            5         322                        Plavac B           832  Adriatic  Croatia  Zlarin Island, central Dalmatia       NaN        NaN        NaN        NaN      NaN  Roman Imperial        C1st AD            1.0        100.0         NaN                      NaN          NaN             NaN                  NaN                                                NaN                                                NaN     False   False        False       False   False         NaN                                                NaN                   NaN                     NaN                                                  .                NaN          NaN
# ...        ...         ...                             ...           ...       ...      ...                              ...       ...        ...        ...        ...      ...             ...            ...            ...          ...         ...                      ...          ...             ...                  ...                                                ...                                                ...       ...     ...          ...         ...     ...         ...                                                ...                   ...                     ...                                                ...                ...          ...
# 1779      9058           0              Olbia Late Roman 2           NaN       NaN    Italy                         Sardinia  40.91148    9.50738        0.0        0.0       0m      Late Roman        C5th AD          400.0        500.0         0.0                      0.0          0.0             NaN                  NaN  R. D'Oriano, Archeologia in Sardegna, 2007,  9...  Three other C5th AD wrecks found during constr...     False   False        False       False   False         NaN                                                NaN                   NaN                     NaN                                                NaN                0.0          NaN
# 1780      9059           0                  Olbia medieval           NaN       NaN    Italy                         Sardinia  40.91148    9.50738        0.0        0.0       0m        Medieval  C11th-15th AD         1000.0       1500.0         0.0                      0.0          0.0             NaN                  NaN  R. D'Oriano, Archeologia in Sardegna, 2007,  9...  Five small wrecks from the eleventh, fourteent...     False   False        False       False   False         NaN                                                NaN                   NaN                     NaN                                                NaN                0.0          NaN
# 1781      9060           0  Isola della Gallinara (Savona)           NaN       NaN    Italy                          Liguria  44.02648    8.22996       50.0       50.0      50m  Roman Republic        C1st BC         -100.0         -1.0         0.0                      0.0          0.0        Campania                  NaN  http://www.archeosub.it/news2003/news0311.htm#...  A mound of intact Dr 1 amphorae and 'other car...      True   False        False       False   False         NaN                                                NaN                   NaN                     NaN                                                NaN                0.0          NaN
# 1782      9061           0                San Vito Lo Capo           NaN       NaN    Italy                           Sicily  38.18825   12.74551        0.0        0.0      NaN          Norman       C12th AD         1100.0       1200.0         0.0                      0.0          0.0             NaN                  NaN  F. Faccenna, Il Relitto di San Vito Lo Capo (2...  A local Sicilian ship carrying amphorae and ja...      True   False        False       False   False         NaN                                                NaN                   NaN                     NaN                                                NaN                0.0          NaN
# 1783      9063           0   Capo Colonna and Capo Alfieri           NaN       NaN    Italy                         Calabria  38.95399   17.17163        0.0        0.0  shallow      Late Roman    C4th-5th AD          300.0        500.0         0.0                      0.0          0.0             NaN                  NaN  http://www.archeomar.it/templates/archeomar/at...       A probable Late Roman shipwreck of amphorae.      True   False        False       False   False         NaN                                                NaN                   NaN                     NaN                                                NaN                0.0          NaN
#
# [1784 rows x 35 columns]

# %% [markdown]
# #### Access one column

# %%
type(df['Sea area'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### What datatype is this?

# %% [markdown]
# #### Access two columns

# %%
df[['Region', 'Sea area']]
# Out:
#                                Region  Sea area
# 0                          Vis Island  Adriatic
# 1                      Kvarner region  Adriatic
# 2                        Mljet island  Adriatic
# 3                       Split channel  Adriatic
# 4     Zlarin Island, central Dalmatia  Adriatic
# ...                               ...       ...
# 1779                         Sardinia       NaN
# 1780                         Sardinia       NaN
# 1781                          Liguria       NaN
# 1782                           Sicily       NaN
# 1783                         Calabria       NaN
#
# [1784 rows x 2 columns]

# %% [markdown]
# Check [here](https://www.w3schools.com/python/pandas/pandas_series.asp).

# %% [markdown]
# #### What datatype is this now?

# %% [markdown]
# #### Get all columns

# %% [markdown]
# ### Get all rows
# - iloc (integer location)
# - loc

# %% [markdown]
# ### 1) iloc

# %%
df.iloc[0]
# Out:
# Wreck ID                                                                   1
# Strauss ID                                                               331
# Name                                                                  Komiza
# Parker Number                                                            NaN
# Sea area                                                            Adriatic
# Country                                                              Croatia
# Region                                                            Vis Island
# Latitude                                                            43.03333
# Longitude                                                           16.08333
# Min depth                                                               30.0
# Max depth                                                               30.0
# Depth                                                                    30m
# Period                                                        Roman Imperial
# Dating                                                           C1st-2nd AD
# Earliest date                                                            1.0
# Latest date                                                            200.0
# Date range                                                               NaN
# Mid point of date range                                                  NaN
# Probability                                                              NaN
# Place of origin                                                        Egypt
# Place of destination                                          Northern Italy
# Reference                  M. Jurišić, Ancient Shipwrecks of the Adriatic...
# Comments                   Completely looted site with sherds of Egyptian...
# Amphorae                                                                True
# Marble                                                                 False
# Columns etc                                                            False
# Sarcophagi                                                             False
# Blocks                                                                 False
# Marble type                                                              NaN
# Other cargo                                                              NaN
# Hull remains                                                             NaN
# Shipboard paraphernalia                                                  NaN
# Ship equipment                                                           NaN
# Estimated tonnage                                                        NaN
# Amphora type                                                             NaN
# Name: 0, dtype: object

# %% [markdown]
# #### How can we get the first two rows?

# %%
df.iloc[0:2]
# Out:
#    Wreck ID  Strauss ID     Name Parker Number  Sea area  Country          Region  Latitude  Longitude  Min depth  Max depth Depth          Period       Dating  Earliest date  Latest date  Date range  Mid point of date range  Probability Place of origin Place of destination                                          Reference                                           Comments  Amphorae  Marble  Columns etc  Sarcophagi  Blocks Marble type Other cargo Hull remains Shipboard paraphernalia Ship equipment  Estimated tonnage Amphora type
# 0         1         331   Komiza           NaN  Adriatic  Croatia      Vis Island  43.03333   16.08333       30.0       30.0   30m  Roman Imperial  C1st-2nd AD            1.0        200.0         NaN                      NaN          NaN           Egypt       Northern Italy  M. Jurišić, Ancient Shipwrecks of the Adriatic...  Completely looted site with sherds of Egyptian...      True   False        False       False   False         NaN         NaN          NaN                     NaN            NaN                NaN          NaN
# 1         2         328  Lokunji           NaN  Adriatic  Croatia  Kvarner region  44.70000   14.28333        4.0       12.0   12m  Roman Imperial     C 1st AD            1.0        100.0         NaN                      NaN          NaN             Cos       Northern Italy  D. Vrsalović, Istraživanja i Zaštita Podmorški...                                                NaN      True   False        False       False   False         NaN         NaN          NaN                     NaN            NaN                NaN          NaN

# %% [markdown]
# #### How can we get the first column of the above df?

# %%
df.iloc[0:2]['Country']
# Out:
# 0    Croatia
# 1    Croatia
# Name: Country, dtype: object

# %% [markdown]
# ### 2) loc
# In this way, we do not get the first, second, etc., row. We get the row that has the index we specify.

# %%
# Out:
#    Sea area  Country
# 0  Adriatic  Croatia
# 1  Adriatic  Croatia

# %% [markdown]
# ### Let's grab some data

# %% [markdown]
# #### Get the Country column

# %%
df.loc["Country"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df.loc["Country"]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
#    1152     # GH#5667 this will fail if the label is not present in the axis.
# -> 1153     return self.obj.xs(label, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:3864, in NDFrame.xs(self, key, axis, level, drop_level)
#    3862             new_index = index[loc]
#    3863 else:
# -> 3864     loc = index.get_loc(key)
#    3866     if isinstance(loc, np.ndarray):
#    3867         if loc.dtype == np.bool_:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'Country'

# %% [markdown]
# #### Count with `.value_counts()`

# %% [markdown]
# ### Set index `.set_index()`

# %% [markdown]
# #### Did the original dataframe change?

# %% [markdown]
# #### let's put the parameter `inplace=True`

# %% [markdown]
# #### What will happen of I look for `df.loc[0]`?

# %% [markdown]
# #### Let's reset the index

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ### Sort `.sort_index(ascending=False)`

# %% [markdown]
# ## Filter

# %% [markdown]
# #### what's the result of the below statement?

# %%
df['Country'] == 'Country'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1779    False
# 1780    False
# 1781    False
# 1782    False
# 1783    False
# Name: Country, Length: 1784, dtype: bool

# %% [markdown]
# #### Combine two filters with `&` = `and`

# %% [markdown]
# #### Combine two filters with `|` = `or`
